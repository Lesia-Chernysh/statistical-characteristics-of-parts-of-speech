# %%
# -*- coding: utf-8 -*-

################################################################################
## Form generated from reading UI file '��������� ������� ���������bLZlms.ui'
##
## Created by: Qt User Interface Compiler version 5.14.1
##
## WARNING! All changes made in this file will be lost when recompiling UI file!
################################################################################

from PyQt5.QtCore import (QCoreApplication, QMetaObject, QObject, QPoint,
   QRect, QSize, QUrl, Qt)
from PyQt5.QtGui import (QBrush, QColor, QConicalGradient, QCursor, QFont,
   QFontDatabase, QIcon, QLinearGradient, QPalette, QPainter, QPixmap,
   QRadialGradient)
from PyQt5 import QtCore, QtGui, QtWidgets
from PyQt5.QtWidgets import *
#from PyQt5 import QtCore, QtWidgets
#from PyQt5.QtWidgets import QTableWidgetItem
from pyqtgraph import PlotWidget, plot
import pyqtgraph as pg
import sys  # We need sys so that we can pass argv to QApplication
import os

import sqlite3

conn = sqlite3.connect('frequency_dict.db')
cursor = conn.cursor()


class Ui_MainWindow(object):
   def setupUi(self, MainWindow):
       if MainWindow.objectName():
           MainWindow.setObjectName("MainWindow")
       MainWindow.resize(891, 600)
       self.centralwidget = QtWidgets.QWidget(MainWindow)
       self.centralwidget.setObjectName("centralwidget")
       self.horizontalLayout_2 = QHBoxLayout(self.centralwidget)
       self.horizontalLayout_2.setObjectName("horizontalLayout_2")
       self.tabWidget = QtWidgets.QTabWidget(self.centralwidget)
       self.tabWidget.setObjectName("tabWidget")
       self.tab = QtWidgets.QWidget()    # іменник
       self.tab.setObjectName("tab")
       self.graphWidget = pg.PlotWidget(self.tab)
       self.graphWidget.setGeometry(QtCore.QRect(600, 50, 391, 331))
       self.graphWidget.setBackground('w')
       self.graphWidget.setLabel("left", "xi")
       self.graphWidget.setLabel("bottom", "ni")
       #Add legend
       self.graphWidget.addLegend()
       #Add grid
       self.graphWidget.showGrid(x=True, y=True)

       self.label = QLabel(self.tab)
       self.label.setObjectName(u"label")
       self.label.setGeometry(QRect(0, 10, 406, 16))
       self.label.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label.setAlignment(QtCore.Qt.AlignCenter)
       self.label_2 = QLabel(self.tab)
       self.label_2.setObjectName(u"label_2")
       self.label_2.setGeometry(QRect(426, 10, 155, 16))
       self.label_2.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_2.setAlignment(QtCore.Qt.AlignCenter)
       self.label_3 = QLabel(self.tab)
       self.label_3.setObjectName(u"label_3")
       self.label_3.setGeometry(QRect(600, 10, 371, 16))
       self.label_3.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_3.setAlignment(QtCore.Qt.AlignCenter)
       self.tabWidget_2 = QTabWidget(self.tab)
       self.tabWidget_2.setObjectName(u"tabWidget_2")
       self.tabWidget_2.setGeometry(QRect(0, 30, 411, 321))
       self.tab_14 = QWidget()
       self.tab_14.setObjectName(u"tab_14")
       self.tableWidget = QtWidgets.QTableWidget(self.tab_14)
       if (self.tableWidget.columnCount() < 7):
           self.tableWidget.setColumnCount(7)
       self.tableWidget.setObjectName("tableWidget")
       self.tableWidget.setGeometry(QRect(0, 0, 406, 291))
       self.tableWidget.setRowCount(0)
       self.tableWidget.setColumnCount(8)
       self.tableWidget.setHorizontalHeaderLabels(['id', 'xi', 'ni', 'xi*ni', 'х̅', 'xi - х̅', '(xi - х̅)^2',
                                                   '(xi - х̅)^2*ni'])
       #Set the tooltips to headings
       self.tableWidget.horizontalHeaderItem(0).setToolTip("Column 1 ")
       self.tableWidget.horizontalHeaderItem(1).setToolTip("Column 2 ")
       self.tableWidget.horizontalHeaderItem(2).setToolTip("Column 3 ")
       self.tableWidget.horizontalHeaderItem(2).setToolTip("Column 4 ")
       self.tableWidget.horizontalHeaderItem(2).setToolTip("Column 5 ")
       self.tableWidget.horizontalHeaderItem(2).setToolTip("Column 6 ")
       self.tableWidget.horizontalHeaderItem(2).setToolTip("Column 7 ")
       # робимо ресайз стовпців по змісту
       self.tableWidget.resizeColumnsToContents()

       self.tabWidget_2.addTab(self.tab_14, "")
       self.tab_15 = QWidget()
       self.tab_15.setObjectName(u"tab_15")
       self.tableWidget_3 = QTableWidget(self.tab_15)
       if (self.tableWidget_3.columnCount() < 8):
           self.tableWidget_3.setColumnCount(8)
       self.tableWidget_3.setObjectName(u"tableWidget_3")
       self.tableWidget_3.setGeometry(QRect(0, 0, 406, 291))
       self.tableWidget_3.setRowCount(0)
       self.tableWidget_3.setColumnCount(8)
       self.tableWidget_3.setHorizontalHeaderLabels(['id', 'xi', 'ni', 'xi*ni', 'х̅', 'xi - х̅', '(xi - х̅)^2',
                                                   '(xi - х̅)^2*ni'])
       #Set the tooltips to headings
       self.tableWidget_3.horizontalHeaderItem(0).setToolTip("Column 1 ")
       self.tableWidget_3.horizontalHeaderItem(1).setToolTip("Column 2 ")
       self.tableWidget_3.horizontalHeaderItem(2).setToolTip("Column 3 ")
       self.tableWidget_3.horizontalHeaderItem(2).setToolTip("Column 4 ")
       self.tableWidget_3.horizontalHeaderItem(2).setToolTip("Column 5 ")
       self.tableWidget_3.horizontalHeaderItem(2).setToolTip("Column 6 ")
       self.tableWidget_3.horizontalHeaderItem(2).setToolTip("Column 7 ")
       # робимо ресайз стовпців по змісту
       self.tableWidget_3.resizeColumnsToContents()
       self.tabWidget_2.addTab(self.tab_15, "")

       self.tabWidget_3 = QTabWidget(self.tab)
       self.tabWidget_3.setObjectName(u"tabWidget_3")
       self.tabWidget_3.setGeometry(QRect(426, 30, 155, 321))
       self.tab_16 = QWidget()
       self.tab_16.setObjectName(u"tab_16")
       self.tableWidget_2 = QTableWidget(self.tab_16)
       if (self.tableWidget_2.columnCount() < 2):
           self.tableWidget_2.setColumnCount(2)
       if (self.tableWidget_2.rowCount() < 12):
           self.tableWidget_2.setRowCount(12)
       self.tableWidget_2.setObjectName(u"tableWidget_2")
       self.tableWidget_2.resizeColumnsToContents()
       self.tableWidget_2.setGeometry(QRect(0, 0, 150, 291))
       self.tableWidget_2.setRowCount(12)
       self.tableWidget_2.setColumnCount(2)

       self.tabWidget_3.addTab(self.tab_16, "")
       self.tab_17 = QWidget()
       self.tab_17.setObjectName(u"tab_17")
       self.tableWidget_4 = QTableWidget(self.tab_17)
       if (self.tableWidget_4.columnCount() < 2):
           self.tableWidget_4.setColumnCount(2)
       if (self.tableWidget_4.rowCount() < 12):
           self.tableWidget_4.setRowCount(12)
       self.tableWidget_4.setObjectName(u"tableWidget_4")
       self.tableWidget_4.setGeometry(QRect(0, 0, 150, 291))
       self.tableWidget_4.setRowCount(12)
       self.tableWidget_4.setColumnCount(2)
       self.tableWidget_4.resizeColumnsToContents()
       self.tabWidget_3.addTab(self.tab_17, "")
       self.tabWidget_4 = QTabWidget(self.tab)
       self.tabWidget_4.setObjectName(u"tabWidget_4")
       self.tabWidget_4.setGeometry(QRect(0, 360, 581, 330))
       self.tab_18 = QWidget()
       self.tab_18.setObjectName(u"tab_18")
       self.label_4 = QLabel(self.tab_18)
       self.label_4.setObjectName(u"label_4")
       self.label_4.setGeometry(QRect(0, 0, 581, 320))
       self.label_4.setStyleSheet("font: 10pt \"Arial\"; padding: 5px;")
       self.label_4.setWordWrap(True)
       self.tabWidget_4.addTab(self.tab_18, "")
       self.tab_19 = QWidget()
       self.tab_19.setObjectName(u"tab_19")
       self.label_5 = QLabel(self.tab_19)
       self.label_5.setObjectName(u"label_5")
       self.label_5.setGeometry(QRect(0, 0, 581, 320))
       self.label_5.setStyleSheet("font: 10pt \"Arial\"; padding: 5px;")
       self.label_5.setWordWrap(True)
       self.tabWidget_4.addTab(self.tab_19, "")
       self.tabWidget.addTab(self.tab, "")
       self.tabWidget_2.raise_()
       self.graphWidget.raise_()
       self.label.raise_()
       self.label_2.raise_()
       self.label_3.raise_()
       self.tabWidget_3.raise_()
       self.tabWidget_4.raise_()



       self.tab_2 = QWidget() #прикметник
       self.tab_2.setObjectName(u"tab_2")
       self.tabWidget.addTab(self.tab_2, "")
       self.graphWidget_2 = pg.PlotWidget(self.tab_2)
       self.graphWidget_2.setGeometry(QtCore.QRect(600, 50, 391, 331))
       self.graphWidget_2.setBackground('w')
       self.graphWidget_2.setLabel("left", "xi")
       self.graphWidget_2.setLabel("bottom", "ni")
       #Add legend
       self.graphWidget_2.addLegend()
       #Add grid
       self.graphWidget_2.showGrid(x=True, y=True)
       self.label_6 = QLabel(self.tab_2)
       self.label_6.setObjectName(u"label_6")
       self.label_6.setGeometry(QRect(0, 10, 406, 16))
       self.label_6.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_6.setAlignment(QtCore.Qt.AlignCenter)
       self.label_7 = QLabel(self.tab_2)
       self.label_7.setObjectName(u"label_7")
       self.label_7.setGeometry(QRect(426, 10, 155, 16))
       self.label_7.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_7.setAlignment(QtCore.Qt.AlignCenter)
       self.label_8 = QLabel(self.tab_2)
       self.label_8.setObjectName(u"label_8")
       self.label_8.setGeometry(QRect(600, 10, 371, 16))
       self.label_8.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_8.setAlignment(QtCore.Qt.AlignCenter)

       self.tabWidget_5 = QTabWidget(self.tab_2)
       self.tabWidget_5.setObjectName(u"tabWidget_5")
       self.tabWidget_5.setGeometry(QRect(0, 30, 411, 321))
       self.tab_20 = QWidget()
       self.tab_20.setObjectName(u"tab_20")
       self.tableWidget_5 = QtWidgets.QTableWidget(self.tab_20)
       if (self.tableWidget_5.columnCount() < 7):
           self.tableWidget_5.setColumnCount(7)
       self.tableWidget_5.setObjectName("tableWidget_5")
       self.tableWidget_5.setGeometry(QRect(0, 0, 406, 291))
       self.tableWidget_5.setRowCount(0)
       self.tableWidget_5.setColumnCount(8)
       self.tableWidget_5.setHorizontalHeaderLabels(['id', 'xi', 'ni', 'xi*ni', 'х̅', 'xi - х̅', '(xi - х̅)^2',
                                                   '(xi - х̅)^2*ni'])
       #Set the tooltips to headings
       self.tableWidget_5.horizontalHeaderItem(0).setToolTip("Column 1 ")
       self.tableWidget_5.horizontalHeaderItem(1).setToolTip("Column 2 ")
       self.tableWidget_5.horizontalHeaderItem(2).setToolTip("Column 3 ")
       self.tableWidget_5.horizontalHeaderItem(2).setToolTip("Column 4 ")
       self.tableWidget_5.horizontalHeaderItem(2).setToolTip("Column 5 ")
       self.tableWidget_5.horizontalHeaderItem(2).setToolTip("Column 6 ")
       self.tableWidget_5.horizontalHeaderItem(2).setToolTip("Column 7 ")
       # робимо ресайз стовпців по змісту
       self.tableWidget_5.resizeColumnsToContents()

       self.tabWidget_5.addTab(self.tab_20, "")
       self.tab_21 = QWidget()
       self.tab_21.setObjectName(u"tab_21")
       self.tableWidget_6 = QTableWidget(self.tab_21)
       if (self.tableWidget_6.columnCount() < 8):
           self.tableWidget_6.setColumnCount(8)
       self.tableWidget_6.setObjectName(u"tableWidget_6")
       self.tableWidget_6.setGeometry(QRect(0, 0, 406, 291))
       self.tableWidget_6.setRowCount(0)
       self.tableWidget_6.setColumnCount(8)
       self.tableWidget_6.setHorizontalHeaderLabels(['id', 'xi', 'ni', 'xi*ni', 'х̅', 'xi - х̅', '(xi - х̅)^2',
                                                   '(xi - х̅)^2*ni'])
       #Set the tooltips to headings
       self.tableWidget_6.horizontalHeaderItem(0).setToolTip("Column 1 ")
       self.tableWidget_6.horizontalHeaderItem(1).setToolTip("Column 2 ")
       self.tableWidget_6.horizontalHeaderItem(2).setToolTip("Column 3 ")
       self.tableWidget_6.horizontalHeaderItem(2).setToolTip("Column 4 ")
       self.tableWidget_6.horizontalHeaderItem(2).setToolTip("Column 5 ")
       self.tableWidget_6.horizontalHeaderItem(2).setToolTip("Column 6 ")
       self.tableWidget_6.horizontalHeaderItem(2).setToolTip("Column 7 ")
       # робимо ресайз стовпців по змісту
       self.tableWidget_6.resizeColumnsToContents()

       self.tabWidget_5.addTab(self.tab_21, "")

       self.tabWidget_6 = QTabWidget(self.tab_2)
       self.tabWidget_6.setObjectName(u"tabWidget_6")
       self.tabWidget_6.setGeometry(QRect(426, 30, 155, 321))
       self.tab_22 = QWidget()
       self.tab_22.setObjectName(u"tab_22")
       self.tableWidget_7 = QTableWidget(self.tab_22)
       if (self.tableWidget_7.columnCount() < 2):
           self.tableWidget_7.setColumnCount(2)
       if (self.tableWidget_7.rowCount() < 12):
           self.tableWidget_7.setRowCount(12)
       self.tableWidget_7.setObjectName(u"tableWidget_7")
       self.tableWidget_7.resizeColumnsToContents()
       self.tableWidget_7.setGeometry(QRect(0, 0, 150, 291))
       self.tableWidget_7.setRowCount(12)
       self.tableWidget_7.setColumnCount(2)

       self.tabWidget_6.addTab(self.tab_22, "")
       self.tab_23 = QWidget()
       self.tab_23.setObjectName(u"tab_23")
       self.tableWidget_8 = QTableWidget(self.tab_23)
       if (self.tableWidget_8.columnCount() < 2):
           self.tableWidget_8.setColumnCount(2)
       if (self.tableWidget_8.rowCount() < 12):
           self.tableWidget_8.setRowCount(12)
       self.tableWidget_8.setObjectName(u"tableWidget_4")
       self.tableWidget_8.setGeometry(QRect(0, 0, 150, 291))
       self.tableWidget_8.setRowCount(12)
       self.tableWidget_8.setColumnCount(2)
       self.tableWidget_8.resizeColumnsToContents()
       self.tabWidget_6.addTab(self.tab_23, "")
       self.tabWidget_7 = QTabWidget(self.tab_2)
       self.tabWidget_7.setObjectName(u"tabWidget_7")
       self.tabWidget_7.setGeometry(QRect(0, 360, 581, 330))
       self.tab_24 = QWidget()
       self.tab_24.setObjectName(u"tab_24")
       self.label_41 = QLabel(self.tab_24)
       self.label_41.setObjectName(u"label_4")
       self.label_41.setGeometry(QRect(0, 0, 581, 320))
       self.label_41.setStyleSheet("font: 10pt \"Arial\"; padding: 5px;")
       self.label_41.setWordWrap(True)
       self.tabWidget_7.addTab(self.tab_24, "")
       self.tab_25 = QWidget()
       self.tab_25.setObjectName(u"tab_25")
       self.label_42 = QLabel(self.tab_25)
       self.label_42.setObjectName(u"label_5")
       self.label_42.setGeometry(QRect(0, 0, 581, 320))
       self.label_42.setStyleSheet("font: 10pt \"Arial\"; padding: 5px;")
       self.label_42.setWordWrap(True)
       self.tabWidget_7.addTab(self.tab_25, "")


       self.tabWidget_5.raise_()
       self.tabWidget_6.raise_()
       self.graphWidget_2.raise_()
       self.label_6.raise_()
       self.label_7.raise_()
       self.label_8.raise_()


       self.tab_3 = QWidget() # дієслово
       self.tab_3.setObjectName(u"tab_3")
       self.tabWidget.addTab(self.tab_3, "")
       self.graphWidget_3 = pg.PlotWidget(self.tab_3)
       self.graphWidget_3.setGeometry(QtCore.QRect(600, 50, 391, 331))
       self.graphWidget_3.setBackground('w')
       self.graphWidget_3.setLabel("left", "xi")
       self.graphWidget_3.setLabel("bottom", "ni")
       #Add legend
       self.graphWidget_3.addLegend()
       #Add grid
       self.graphWidget_3.showGrid(x=True, y=True)
       self.label_9 = QLabel(self.tab_3)
       self.label_9.setObjectName(u"label_9")
       self.label_9.setGeometry(QRect(0, 10, 406, 16))
       self.label_9.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_9.setAlignment(QtCore.Qt.AlignCenter)
       self.label_10 = QLabel(self.tab_3)
       self.label_10.setObjectName(u"label_10")
       self.label_10.setGeometry(QRect(426, 10, 155, 16))
       self.label_10.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_10.setAlignment(QtCore.Qt.AlignCenter)
       self.label_11 = QLabel(self.tab_3)
       self.label_11.setObjectName(u"label_11")
       self.label_11.setGeometry(QRect(600, 10, 371, 16))
       self.label_11.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_11.setAlignment(QtCore.Qt.AlignCenter)

       self.tabWidget_8 = QTabWidget(self.tab_3)
       self.tabWidget_8.setObjectName(u"tabWidget_8")
       self.tabWidget_8.setGeometry(QRect(0, 30, 411, 321))
       self.tab_26 = QWidget()
       self.tab_26.setObjectName(u"tab_26")
       self.tableWidget_9 = QtWidgets.QTableWidget(self.tab_26)
       if (self.tableWidget_9.columnCount() < 7):
           self.tableWidget_9.setColumnCount(7)
       self.tableWidget_9.setObjectName("tableWidget_9")
       self.tableWidget_9.setGeometry(QRect(0, 0, 406, 291))
       self.tableWidget_9.setRowCount(0)
       self.tableWidget_9.setColumnCount(8)
       self.tableWidget_9.setHorizontalHeaderLabels(['id', 'xi', 'ni', 'xi*ni', 'х̅', 'xi - х̅', '(xi - х̅)^2',
                                                   '(xi - х̅)^2*ni'])
       #Set the tooltips to headings
       self.tableWidget_9.horizontalHeaderItem(0).setToolTip("Column 1 ")
       self.tableWidget_9.horizontalHeaderItem(1).setToolTip("Column 2 ")
       self.tableWidget_9.horizontalHeaderItem(2).setToolTip("Column 3 ")
       self.tableWidget_9.horizontalHeaderItem(2).setToolTip("Column 4 ")
       self.tableWidget_9.horizontalHeaderItem(2).setToolTip("Column 5 ")
       self.tableWidget_9.horizontalHeaderItem(2).setToolTip("Column 6 ")
       self.tableWidget_9.horizontalHeaderItem(2).setToolTip("Column 7 ")
       # робимо ресайз стовпців по змісту
       self.tableWidget_9.resizeColumnsToContents()

       self.tabWidget_8.addTab(self.tab_26, "")
       self.tab_27 = QWidget()
       self.tab_27.setObjectName(u"tab_27")
       self.tableWidget_10 = QTableWidget(self.tab_27)
       if (self.tableWidget_10.columnCount() < 8):
           self.tableWidget_10.setColumnCount(8)
       self.tableWidget_10.setObjectName(u"tableWidget_10")
       self.tableWidget_10.setGeometry(QRect(0, 0, 406, 291))
       self.tableWidget_10.setRowCount(0)
       self.tableWidget_10.setColumnCount(8)
       self.tableWidget_10.setHorizontalHeaderLabels(['id', 'xi', 'ni', 'xi*ni', 'х̅', 'xi - х̅', '(xi - х̅)^2',
                                                   '(xi - х̅)^2*ni'])
       #Set the tooltips to headings
       self.tableWidget_10.horizontalHeaderItem(0).setToolTip("Column 1 ")
       self.tableWidget_10.horizontalHeaderItem(1).setToolTip("Column 2 ")
       self.tableWidget_10.horizontalHeaderItem(2).setToolTip("Column 3 ")
       self.tableWidget_10.horizontalHeaderItem(2).setToolTip("Column 4 ")
       self.tableWidget_10.horizontalHeaderItem(2).setToolTip("Column 5 ")
       self.tableWidget_10.horizontalHeaderItem(2).setToolTip("Column 6 ")
       self.tableWidget_10.horizontalHeaderItem(2).setToolTip("Column 7 ")
       # робимо ресайз стовпців по змісту
       self.tableWidget_10.resizeColumnsToContents()

       self.tabWidget_8.addTab(self.tab_27, "")

       self.tabWidget_9 = QTabWidget(self.tab_3)
       self.tabWidget_9.setObjectName(u"tabWidget_9")
       self.tabWidget_9.setGeometry(QRect(426, 30, 155, 321))
       self.tab_28 = QWidget()
       self.tab_28.setObjectName(u"tab_28")
       self.tableWidget_11 = QTableWidget(self.tab_28)
       if (self.tableWidget_11.columnCount() < 2):
           self.tableWidget_11.setColumnCount(2)
       if (self.tableWidget_11.rowCount() < 12):
           self.tableWidget_11.setRowCount(12)
       self.tableWidget_11.setObjectName(u"tableWidget_11")
       self.tableWidget_11.resizeColumnsToContents()
       self.tableWidget_11.setGeometry(QRect(0, 0, 150, 291))
       self.tableWidget_11.setRowCount(12)
       self.tableWidget_11.setColumnCount(2)

       self.tabWidget_9.addTab(self.tab_28, "")
       self.tab_29 = QWidget()
       self.tab_29.setObjectName(u"tab_29")
       self.tableWidget_12 = QTableWidget(self.tab_29)
       if (self.tableWidget_12.columnCount() < 2):
           self.tableWidget_12.setColumnCount(2)
       if (self.tableWidget_12.rowCount() < 12):
           self.tableWidget_12.setRowCount(12)
       self.tableWidget_12.setObjectName(u"tableWidget_12")
       self.tableWidget_12.setGeometry(QRect(0, 0, 150, 291))
       self.tableWidget_12.setRowCount(12)
       self.tableWidget_12.setColumnCount(2)
       self.tableWidget_12.resizeColumnsToContents()
       self.tabWidget_9.addTab(self.tab_29, "")
       self.tabWidget_10 = QTabWidget(self.tab_3)
       self.tabWidget_10.setObjectName(u"tabWidget_10")
       self.tabWidget_10.setGeometry(QRect(0, 360, 581, 330))
       self.tab_30 = QWidget()
       self.tab_30.setObjectName(u"tab_30")
       self.label_43 = QLabel(self.tab_30)
       self.label_43.setObjectName(u"label_43")
       self.label_43.setGeometry(QRect(0, 0, 581, 320))
       self.tabWidget_10.addTab(self.tab_30, "")
       self.tab_31 = QWidget()
       self.tab_31.setObjectName(u"tab_31")
       self.label_44 = QLabel(self.tab_31)
       self.label_44.setObjectName(u"label_44")
       self.label_44.setGeometry(QRect(0, 0, 581, 320))
       self.tabWidget_10.addTab(self.tab_31, "")


       self.tabWidget_8.raise_()
       self.tabWidget_9.raise_()


       self.graphWidget_3.raise_()
       self.label_9.raise_()
       self.label_10.raise_()
       self.label_11.raise_()

       self.tab_4 = QWidget() # займенник
       self.tab_4.setObjectName(u"tab_4")
       self.tabWidget.addTab(self.tab_4, "")
       self.graphWidget_4 = pg.PlotWidget(self.tab_4)
       self.graphWidget_4.setGeometry(QtCore.QRect(600, 50, 391, 331))
       self.graphWidget_4.setBackground('w')
       self.graphWidget_4.setLabel("left", "xi")
       self.graphWidget_4.setLabel("bottom", "ni")
       #Add legend
       self.graphWidget_4.addLegend()
       #Add grid
       self.graphWidget_4.showGrid(x=True, y=True)
       self.label_12 = QLabel(self.tab_4)
       self.label_12.setObjectName(u"label_12")
       self.label_12.setGeometry(QRect(0, 10, 406, 16))
       self.label_12.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_12.setAlignment(QtCore.Qt.AlignCenter)
       self.label_13 = QLabel(self.tab_4)
       self.label_13.setObjectName(u"label_13")
       self.label_13.setGeometry(QRect(426, 10, 155, 16))
       self.label_13.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_13.setAlignment(QtCore.Qt.AlignCenter)
       self.label_14 = QLabel(self.tab_4)
       self.label_14.setObjectName(u"label_14")
       self.label_14.setGeometry(QRect(600, 10, 371, 16))
       self.label_14.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_14.setAlignment(QtCore.Qt.AlignCenter)

       self.tabWidget_11 = QTabWidget(self.tab_4)
       self.tabWidget_11.setObjectName(u"tabWidget_11")
       self.tabWidget_11.setGeometry(QRect(0, 30, 411, 321))
       self.tab_32 = QWidget()
       self.tab_32.setObjectName(u"tab_32")
       self.tableWidget_13 = QtWidgets.QTableWidget(self.tab_32)
       if (self.tableWidget_13.columnCount() < 7):
           self.tableWidget_13.setColumnCount(7)
       self.tableWidget_13.setObjectName("tableWidget_13")
       self.tableWidget_13.setGeometry(QRect(0, 0, 406, 291))
       self.tableWidget_13.setRowCount(0)
       self.tableWidget_13.setColumnCount(8)
       self.tableWidget_13.setHorizontalHeaderLabels(['id', 'xi', 'ni', 'xi*ni', 'х̅', 'xi - х̅', '(xi - х̅)^2',
                                                   '(xi - х̅)^2*ni'])
       #Set the tooltips to headings
       self.tableWidget_13.horizontalHeaderItem(0).setToolTip("Column 1 ")
       self.tableWidget_13.horizontalHeaderItem(1).setToolTip("Column 2 ")
       self.tableWidget_13.horizontalHeaderItem(2).setToolTip("Column 3 ")
       self.tableWidget_13.horizontalHeaderItem(2).setToolTip("Column 4 ")
       self.tableWidget_13.horizontalHeaderItem(2).setToolTip("Column 5 ")
       self.tableWidget_13.horizontalHeaderItem(2).setToolTip("Column 6 ")
       self.tableWidget_13.horizontalHeaderItem(2).setToolTip("Column 7 ")
       # робимо ресайз стовпців по змісту
       #self.tableWidget_13.resizeColumnsToContents()

       self.tabWidget_11.addTab(self.tab_32, "")
       self.tab_33 = QWidget()
       self.tab_33.setObjectName(u"tab_33")
       self.tableWidget_14 = QTableWidget(self.tab_33)
       if (self.tableWidget_14.columnCount() < 8):
           self.tableWidget_14.setColumnCount(8)
       self.tableWidget_14.setObjectName(u"tableWidget_10")
       self.tableWidget_14.setGeometry(QRect(0, 0, 406, 291))
       self.tableWidget_14.setRowCount(0)
       self.tableWidget_14.setColumnCount(8)
       self.tableWidget_14.setHorizontalHeaderLabels(['id', 'xi', 'ni', 'xi*ni', 'х̅', 'xi - х̅', '(xi - х̅)^2',
                                                   '(xi - х̅)^2*ni'])
       #Set the tooltips to headings
       self.tableWidget_14.horizontalHeaderItem(0).setToolTip("Column 1 ")
       self.tableWidget_14.horizontalHeaderItem(1).setToolTip("Column 2 ")
       self.tableWidget_14.horizontalHeaderItem(2).setToolTip("Column 3 ")
       self.tableWidget_14.horizontalHeaderItem(2).setToolTip("Column 4 ")
       self.tableWidget_14.horizontalHeaderItem(2).setToolTip("Column 5 ")
       self.tableWidget_14.horizontalHeaderItem(2).setToolTip("Column 6 ")
       self.tableWidget_14.horizontalHeaderItem(2).setToolTip("Column 7 ")
       # робимо ресайз стовпців по змісту
       #self.tableWidget_14.resizeColumnsToContents()

       self.tabWidget_11.addTab(self.tab_33, "")

       self.tabWidget_12 = QTabWidget(self.tab_4)
       self.tabWidget_12.setObjectName(u"tabWidget_12")
       self.tabWidget_12.setGeometry(QRect(426, 30, 155, 321))
       self.tab_34 = QWidget()
       self.tab_34.setObjectName(u"tab_34")
       self.tableWidget_15 = QTableWidget(self.tab_34)
       if (self.tableWidget_15.columnCount() < 2):
           self.tableWidget_15.setColumnCount(2)
       if (self.tableWidget_15.rowCount() < 12):
           self.tableWidget_15.setRowCount(12)
       self.tableWidget_15.setObjectName(u"tableWidget_11")
       self.tableWidget_15.resizeColumnsToContents()
       self.tableWidget_15.setGeometry(QRect(0, 0, 150, 291))
       self.tableWidget_15.setRowCount(12)
       self.tableWidget_15.setColumnCount(2)

       self.tabWidget_12.addTab(self.tab_34, "")
       self.tab_35 = QWidget()
       self.tab_35.setObjectName(u"tab_35")
       self.tableWidget_16 = QTableWidget(self.tab_35)
       if (self.tableWidget_16.columnCount() < 2):
           self.tableWidget_16.setColumnCount(2)
       if (self.tableWidget_16.rowCount() < 12):
           self.tableWidget_16.setRowCount(12)
       self.tableWidget_16.setObjectName(u"tableWidget_12")
       self.tableWidget_16.setGeometry(QRect(0, 0, 150, 291))
       self.tableWidget_16.setRowCount(12)
       self.tableWidget_16.setColumnCount(2)
       self.tableWidget_16.resizeColumnsToContents()
       self.tabWidget_12.addTab(self.tab_35, "")
       self.tabWidget_13 = QTabWidget(self.tab_4)
       self.tabWidget_13.setObjectName(u"tabWidget_13")
       self.tabWidget_13.setGeometry(QRect(0, 360, 581, 330))
       self.tab_36 = QWidget()
       self.tab_36.setObjectName(u"tab_36")
       self.label_45 = QLabel(self.tab_36)
       self.label_45.setObjectName(u"label_45")
       self.label_45.setGeometry(QRect(0, 0, 581, 320))
       self.tabWidget_13.addTab(self.tab_36, "")
       self.tab_37 = QWidget()
       self.tab_37.setObjectName(u"tab_37")
       self.label_46 = QLabel(self.tab_37)
       self.label_46.setObjectName(u"label_46")
       self.label_46.setGeometry(QRect(0, 0, 581, 320))
       self.tabWidget_13.addTab(self.tab_37, "")


       self.tabWidget_11.raise_()
       self.tabWidget_12.raise_()


       self.graphWidget_4.raise_()
       self.label_12.raise_()
       self.label_13.raise_()
       self.label_14.raise_()



       self.tab_5 = QWidget() # прислівник
       self.tab_5.setObjectName(u"tab_5")
       self.tabWidget.addTab(self.tab_5, "")
       self.graphWidget_5 = pg.PlotWidget(self.tab_5)
       self.graphWidget_5.setGeometry(QtCore.QRect(600, 50, 391, 331))
       self.graphWidget_5.setBackground('w')
       self.graphWidget_5.setLabel("left", "xi")
       self.graphWidget_5.setLabel("bottom", "ni")
       #Add legend
       self.graphWidget_5.addLegend()
       #Add grid
       self.graphWidget_5.showGrid(x=True, y=True)
       self.label_15 = QLabel(self.tab_5)
       self.label_15.setObjectName(u"label_15")
       self.label_15.setGeometry(QRect(0, 10, 406, 16))
       self.label_15.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_15.setAlignment(QtCore.Qt.AlignCenter)
       self.label_16 = QLabel(self.tab_5)
       self.label_16.setObjectName(u"label_16")
       self.label_16.setGeometry(QRect(426, 10, 155, 16))
       self.label_16.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_16.setAlignment(QtCore.Qt.AlignCenter)
       self.label_17 = QLabel(self.tab_5)
       self.label_17.setObjectName(u"label_17")
       self.label_17.setGeometry(QRect(600, 10, 371, 16))
       self.label_17.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_17.setAlignment(QtCore.Qt.AlignCenter)


       self.tabWidget_14 = QTabWidget(self.tab_5)
       self.tabWidget_14.setObjectName(u"tabWidget_14")
       self.tabWidget_14.setGeometry(QRect(0, 30, 411, 321))
       self.tab_38 = QWidget()
       self.tab_38.setObjectName(u"tab_38")
       self.tableWidget_17 = QtWidgets.QTableWidget(self.tab_38)
       if (self.tableWidget_17.columnCount() < 7):
           self.tableWidget_17.setColumnCount(7)
       self.tableWidget_17.setObjectName("tableWidget_17")
       self.tableWidget_17.setGeometry(QRect(0, 0, 406, 291))
       self.tableWidget_17.setRowCount(0)
       self.tableWidget_17.setColumnCount(8)
       self.tableWidget_17.setHorizontalHeaderLabels(['id', 'xi', 'ni', 'xi*ni', 'х̅', 'xi - х̅', '(xi - х̅)^2',
                                                   '(xi - х̅)^2*ni'])
       #Set the tooltips to headings
       self.tableWidget_17.horizontalHeaderItem(0).setToolTip("Column 1 ")
       self.tableWidget_17.horizontalHeaderItem(1).setToolTip("Column 2 ")
       self.tableWidget_17.horizontalHeaderItem(2).setToolTip("Column 3 ")
       self.tableWidget_17.horizontalHeaderItem(2).setToolTip("Column 4 ")
       self.tableWidget_17.horizontalHeaderItem(2).setToolTip("Column 5 ")
       self.tableWidget_17.horizontalHeaderItem(2).setToolTip("Column 6 ")
       self.tableWidget_17.horizontalHeaderItem(2).setToolTip("Column 7 ")
       # робимо ресайз стовпців по змісту
       #self.tableWidget_13.resizeColumnsToContents()

       self.tabWidget_14.addTab(self.tab_38, "")
       self.tab_39 = QWidget()
       self.tab_39.setObjectName(u"tab_39")
       self.tableWidget_18 = QTableWidget(self.tab_39)
       if (self.tableWidget_18.columnCount() < 8):
           self.tableWidget_18.setColumnCount(8)
       self.tableWidget_18.setObjectName(u"tableWidget_10")
       self.tableWidget_18.setGeometry(QRect(0, 0, 406, 291))
       self.tableWidget_18.setRowCount(0)
       self.tableWidget_18.setColumnCount(8)
       self.tableWidget_18.setHorizontalHeaderLabels(['id', 'xi', 'ni', 'xi*ni', 'х̅', 'xi - х̅', '(xi - х̅)^2',
                                                   '(xi - х̅)^2*ni'])
       #Set the tooltips to headings
       self.tableWidget_18.horizontalHeaderItem(0).setToolTip("Column 1 ")
       self.tableWidget_18.horizontalHeaderItem(1).setToolTip("Column 2 ")
       self.tableWidget_18.horizontalHeaderItem(2).setToolTip("Column 3 ")
       self.tableWidget_18.horizontalHeaderItem(2).setToolTip("Column 4 ")
       self.tableWidget_18.horizontalHeaderItem(2).setToolTip("Column 5 ")
       self.tableWidget_18.horizontalHeaderItem(2).setToolTip("Column 6 ")
       self.tableWidget_18.horizontalHeaderItem(2).setToolTip("Column 7 ")
       # робимо ресайз стовпців по змісту
       #self.tableWidget_14.resizeColumnsToContents()

       self.tabWidget_14.addTab(self.tab_39, "")

       self.tabWidget_15 = QTabWidget(self.tab_5)
       self.tabWidget_15.setObjectName(u"tabWidget_15")
       self.tabWidget_15.setGeometry(QRect(426, 30, 155, 321))
       self.tab_40 = QWidget()
       self.tab_40.setObjectName(u"tab_40")
       self.tableWidget_19 = QTableWidget(self.tab_40)
       if (self.tableWidget_19.columnCount() < 2):
           self.tableWidget_19.setColumnCount(2)
       if (self.tableWidget_19.rowCount() < 12):
           self.tableWidget_19.setRowCount(12)
       self.tableWidget_19.setObjectName(u"tableWidget_11")
       self.tableWidget_19.resizeColumnsToContents()
       self.tableWidget_19.setGeometry(QRect(0, 0, 150, 291))
       self.tableWidget_19.setRowCount(12)
       self.tableWidget_19.setColumnCount(2)

       self.tabWidget_15.addTab(self.tab_40, "")
       self.tab_41 = QWidget()
       self.tab_41.setObjectName(u"tab_41")
       self.tableWidget_20 = QTableWidget(self.tab_41)
       if (self.tableWidget_20.columnCount() < 2):
           self.tableWidget_20.setColumnCount(2)
       if (self.tableWidget_20.rowCount() < 12):
           self.tableWidget_20.setRowCount(12)
       self.tableWidget_20.setObjectName(u"tableWidget_20")
       self.tableWidget_20.setGeometry(QRect(0, 0, 150, 291))
       self.tableWidget_20.setRowCount(12)
       self.tableWidget_20.setColumnCount(2)
       self.tableWidget_20.resizeColumnsToContents()
       self.tabWidget_15.addTab(self.tab_41, "")
       self.tabWidget_16 = QTabWidget(self.tab_5)
       self.tabWidget_16.setObjectName(u"tabWidget_16")
       self.tabWidget_16.setGeometry(QRect(0, 360, 581, 330))
       self.tab_42 = QWidget()
       self.tab_42.setObjectName(u"tab_42")
       self.label_47 = QLabel(self.tab_42)
       self.label_47.setObjectName(u"label_47")
       self.label_47.setGeometry(QRect(0, 0, 581, 320))
       self.tabWidget_16.addTab(self.tab_42, "")
       self.tab_43 = QWidget()
       self.tab_43.setObjectName(u"tab_43")
       self.label_48 = QLabel(self.tab_43)
       self.label_48.setObjectName(u"label_48")
       self.label_48.setGeometry(QRect(0, 0, 581, 320))
       self.tabWidget_16.addTab(self.tab_43, "")


       self.tabWidget_14.raise_()
       self.tabWidget_15.raise_()

       self.graphWidget_5.raise_()
       self.label_15.raise_()
       self.label_16.raise_()
       self.label_17.raise_()



       self.tab_6 = QWidget() # прийменник
       self.tab_6.setObjectName(u"tab_6")
       self.tabWidget.addTab(self.tab_6, "")
       self.graphWidget_6 = pg.PlotWidget(self.tab_6)
       self.graphWidget_6.setGeometry(QtCore.QRect(600, 50, 391, 331))
       self.graphWidget_6.setBackground('w')
       self.graphWidget_6.setLabel("left", "xi")
       self.graphWidget_6.setLabel("bottom", "ni")
       #Add legend
       self.graphWidget_6.addLegend()
       #Add grid
       self.graphWidget_6.showGrid(x=True, y=True)
       self.label_18 = QLabel(self.tab_6)
       self.label_18.setObjectName(u"label_18")
       self.label_18.setGeometry(QRect(0, 10, 406, 16))
       self.label_18.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_18.setAlignment(QtCore.Qt.AlignCenter)
       self.label_19 = QLabel(self.tab_6)
       self.label_19.setObjectName(u"label_19")
       self.label_19.setGeometry(QRect(426, 10, 155, 16))
       self.label_19.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_19.setAlignment(QtCore.Qt.AlignCenter)
       self.label_20 = QLabel(self.tab_6)
       self.label_20.setObjectName(u"label_20")
       self.label_20.setGeometry(QRect(600, 10, 371, 16))
       self.label_20.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_20.setAlignment(QtCore.Qt.AlignCenter)



       self.tabWidget_17 = QTabWidget(self.tab_6)
       self.tabWidget_17.setObjectName(u"tabWidget_17")
       self.tabWidget_17.setGeometry(QRect(0, 30, 411, 321))
       self.tab_44 = QWidget()
       self.tab_44.setObjectName(u"tab_44")
       self.tableWidget_21 = QtWidgets.QTableWidget(self.tab_44)
       if (self.tableWidget_21.columnCount() < 7):
           self.tableWidget_21.setColumnCount(7)
       self.tableWidget_21.setObjectName("tableWidget_21")
       self.tableWidget_21.setGeometry(QRect(0, 0, 406, 291))
       self.tableWidget_21.setRowCount(0)
       self.tableWidget_21.setColumnCount(8)
       self.tableWidget_21.setHorizontalHeaderLabels(['id', 'xi', 'ni', 'xi*ni', 'х̅', 'xi - х̅', '(xi - х̅)^2',
                                                   '(xi - х̅)^2*ni'])
       #Set the tooltips to headings
       self.tableWidget_21.horizontalHeaderItem(0).setToolTip("Column 1 ")
       self.tableWidget_21.horizontalHeaderItem(1).setToolTip("Column 2 ")
       self.tableWidget_21.horizontalHeaderItem(2).setToolTip("Column 3 ")
       self.tableWidget_21.horizontalHeaderItem(2).setToolTip("Column 4 ")
       self.tableWidget_21.horizontalHeaderItem(2).setToolTip("Column 5 ")
       self.tableWidget_21.horizontalHeaderItem(2).setToolTip("Column 6 ")
       self.tableWidget_21.horizontalHeaderItem(2).setToolTip("Column 7 ")
       # робимо ресайз стовпців по змісту
       #self.tableWidget_13.resizeColumnsToContents()

       self.tabWidget_17.addTab(self.tab_44, "")
       self.tab_45 = QWidget()
       self.tab_45.setObjectName(u"tab_45")
       self.tableWidget_22 = QTableWidget(self.tab_45)
       if (self.tableWidget_22.columnCount() < 8):
           self.tableWidget_22.setColumnCount(8)
       self.tableWidget_22.setObjectName(u"tableWidget_10")
       self.tableWidget_22.setGeometry(QRect(0, 0, 406, 291))
       self.tableWidget_22.setRowCount(0)
       self.tableWidget_22.setColumnCount(8)
       self.tableWidget_22.setHorizontalHeaderLabels(['id', 'xi', 'ni', 'xi*ni', 'х̅', 'xi - х̅', '(xi - х̅)^2',
                                                   '(xi - х̅)^2*ni'])
       #Set the tooltips to headings
       self.tableWidget_22.horizontalHeaderItem(0).setToolTip("Column 1 ")
       self.tableWidget_22.horizontalHeaderItem(1).setToolTip("Column 2 ")
       self.tableWidget_22.horizontalHeaderItem(2).setToolTip("Column 3 ")
       self.tableWidget_22.horizontalHeaderItem(2).setToolTip("Column 4 ")
       self.tableWidget_22.horizontalHeaderItem(2).setToolTip("Column 5 ")
       self.tableWidget_22.horizontalHeaderItem(2).setToolTip("Column 6 ")
       self.tableWidget_22.horizontalHeaderItem(2).setToolTip("Column 7 ")
       # робимо ресайз стовпців по змісту
       #self.tableWidget_14.resizeColumnsToContents()

       self.tabWidget_17.addTab(self.tab_45, "")

       self.tabWidget_18 = QTabWidget(self.tab_6)
       self.tabWidget_18.setObjectName(u"tabWidget_18")
       self.tabWidget_18.setGeometry(QRect(426, 30, 155, 321))
       self.tab_46 = QWidget()
       self.tab_46.setObjectName(u"tab_46")
       self.tableWidget_23 = QTableWidget(self.tab_46)
       if (self.tableWidget_23.columnCount() < 2):
           self.tableWidget_23.setColumnCount(2)
       if (self.tableWidget_23.rowCount() < 12):
           self.tableWidget_23.setRowCount(12)
       self.tableWidget_23.setObjectName(u"tableWidget_11")
       self.tableWidget_23.resizeColumnsToContents()
       self.tableWidget_23.setGeometry(QRect(0, 0, 150, 291))
       self.tableWidget_23.setRowCount(12)
       self.tableWidget_23.setColumnCount(2)

       self.tabWidget_18.addTab(self.tab_46, "")
       self.tab_47 = QWidget()
       self.tab_47.setObjectName(u"tab_47")
       self.tableWidget_24 = QTableWidget(self.tab_47)
       if (self.tableWidget_24.columnCount() < 2):
           self.tableWidget_24.setColumnCount(2)
       if (self.tableWidget_24.rowCount() < 12):
           self.tableWidget_24.setRowCount(12)
       self.tableWidget_24.setObjectName(u"tableWidget_24")
       self.tableWidget_24.setGeometry(QRect(0, 0, 150, 291))
       self.tableWidget_24.setRowCount(12)
       self.tableWidget_24.setColumnCount(2)
       self.tableWidget_24.resizeColumnsToContents()
       self.tabWidget_18.addTab(self.tab_47, "")
       self.tabWidget_19 = QTabWidget(self.tab_6)
       self.tabWidget_19.setObjectName(u"tabWidget_19")
       self.tabWidget_19.setGeometry(QRect(0, 360, 581, 330))
       self.tab_48 = QWidget()
       self.tab_48.setObjectName(u"tab_48")
       self.label_49 = QLabel(self.tab_48)
       self.label_49.setObjectName(u"label_49")
       self.label_49.setGeometry(QRect(0, 0, 581, 320))
       self.tabWidget_19.addTab(self.tab_48, "")
       self.tab_49 = QWidget()
       self.tab_49.setObjectName(u"tab_49")
       self.label_50 = QLabel(self.tab_49)
       self.label_50.setObjectName(u"label_48")
       self.label_50.setGeometry(QRect(0, 0, 581, 320))
       self.tabWidget_19.addTab(self.tab_49, "")


       self.tabWidget_17.raise_()
       self.tabWidget_18.raise_()



       self.graphWidget_6.raise_()
       self.label_18.raise_()
       self.label_19.raise_()
       self.label_20.raise_()



       self.tab_7 = QWidget() # дієприслівник
       self.tab_7.setObjectName(u"tab_7")
       self.tabWidget.addTab(self.tab_7, "")
       self.graphicsView_7 = QGraphicsView(self.tab_7)
       self.graphicsView_7.setObjectName(u"graphicsView_7")
       self.graphicsView_7.setGeometry(QtCore.QRect(600, 50, 371, 301))
       self.label_21 = QLabel(self.tab_7)
       self.label_21.setObjectName(u"label_21")
       self.label_21.setGeometry(QRect(0, 10, 406, 16))
       self.label_21.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_21.setAlignment(QtCore.Qt.AlignCenter)
       self.label_22 = QLabel(self.tab_7)
       self.label_22.setObjectName(u"label_22")
       self.label_22.setGeometry(QRect(426, 10, 155, 16))
       self.label_22.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_22.setAlignment(QtCore.Qt.AlignCenter)
       self.label_23 = QLabel(self.tab_7)
       self.label_23.setObjectName(u"label_23")
       self.label_23.setGeometry(QRect(600, 10, 371, 16))
       self.label_23.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_23.setAlignment(QtCore.Qt.AlignCenter)


       self.graphicsView_7.raise_()
       self.label_21.raise_()
       self.label_22.raise_()
       self.label_23.raise_()



       self.tab_8 = QWidget() # сполучник
       self.tab_8.setObjectName(u"tab_8")
       self.tabWidget.addTab(self.tab_8, "")
       self.graphicsView_8 = QGraphicsView(self.tab_8)
       self.graphicsView_8.setObjectName(u"graphicsView_8")
       self.graphicsView_8.setGeometry(QtCore.QRect(600, 50, 371, 301))
       self.label_24 = QLabel(self.tab_8)
       self.label_24.setObjectName(u"label_24")
       self.label_24.setGeometry(QRect(0, 10, 406, 16))
       self.label_24.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_24.setAlignment(QtCore.Qt.AlignCenter)
       self.label_25 = QLabel(self.tab_8)
       self.label_25.setObjectName(u"label_25")
       self.label_25.setGeometry(QRect(426, 10, 155, 16))
       self.label_25.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_25.setAlignment(QtCore.Qt.AlignCenter)
       self.label_26 = QLabel(self.tab_8)
       self.label_26.setObjectName(u"label_26")
       self.label_26.setGeometry(QRect(600, 10, 371, 16))
       self.label_26.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_26.setAlignment(QtCore.Qt.AlignCenter)


       self.graphicsView_8.raise_()
       self.label_24.raise_()
       self.label_25.raise_()
       self.label_26.raise_()


       self.tab_9 = QWidget() # частка
       self.tab_9.setObjectName(u"tab_9")
       self.tabWidget.addTab(self.tab_9, "")
       self.graphicsView_9 = QGraphicsView(self.tab_9)
       self.graphicsView_9.setObjectName(u"graphicsView_9")
       self.graphicsView_9.setGeometry(QtCore.QRect(600, 50, 371, 301))
       self.label_27 = QLabel(self.tab_9)
       self.label_27.setObjectName(u"label_27")
       self.label_27.setGeometry(QRect(0, 10, 406, 16))
       self.label_27.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_27.setAlignment(QtCore.Qt.AlignCenter)
       self.label_28 = QLabel(self.tab_9)
       self.label_28.setObjectName(u"label_28")
       self.label_28.setGeometry(QRect(426, 10, 155, 16))
       self.label_28.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_28.setAlignment(QtCore.Qt.AlignCenter)
       self.label_29 = QLabel(self.tab_9)
       self.label_29.setObjectName(u"label_29")
       self.label_29.setGeometry(QRect(600, 10, 371, 16))
       self.label_29.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_29.setAlignment(QtCore.Qt.AlignCenter)


       self.graphicsView_9.raise_()
       self.label_27.raise_()
       self.label_28.raise_()
       self.label_29.raise_()



       self.tab_10 = QWidget() # предикатив
       self.tab_10.setObjectName(u"tab_10")
       self.tabWidget.addTab(self.tab_10, "")
       self.graphicsView_10 = QGraphicsView(self.tab_10)
       self.graphicsView_10.setObjectName(u"graphicsView_10")
       self.graphicsView_10.setGeometry(QtCore.QRect(600, 50, 371, 301))
       self.label_30 = QLabel(self.tab_10)
       self.label_30.setObjectName(u"label_30")
       self.label_30.setGeometry(QRect(0, 10, 406, 16))
       self.label_30.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_30.setAlignment(QtCore.Qt.AlignCenter)
       self.label_31 = QLabel(self.tab_10)
       self.label_31.setObjectName(u"label_31")
       self.label_31.setGeometry(QRect(426, 10, 155, 16))
       self.label_31.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_31.setAlignment(QtCore.Qt.AlignCenter)
       self.label_32 = QLabel(self.tab_10)
       self.label_32.setObjectName(u"label_29")
       self.label_32.setGeometry(QRect(600, 10, 371, 16))
       self.label_32.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_32.setAlignment(QtCore.Qt.AlignCenter)


       self.graphicsView_10.raise_()
       self.label_30.raise_()
       self.label_31.raise_()
       self.label_32.raise_()



       self.tab_11 = QWidget() # компаратив
       self.tab_11.setObjectName(u"tab_11")
       self.tabWidget.addTab(self.tab_11, "")
       self.graphicsView_11 = QGraphicsView(self.tab_11)
       self.graphicsView_11.setObjectName(u"graphicsView_11")
       self.graphicsView_11.setGeometry(QtCore.QRect(600, 50, 371, 301))
       self.label_33 = QLabel(self.tab_11)
       self.label_33.setObjectName(u"label_33")
       self.label_33.setGeometry(QRect(0, 10, 406, 16))
       self.label_33.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_33.setAlignment(QtCore.Qt.AlignCenter)
       self.label_34 = QLabel(self.tab_11)
       self.label_34.setObjectName(u"label_34")
       self.label_34.setGeometry(QRect(426, 10, 155, 16))
       self.label_34.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_34.setAlignment(QtCore.Qt.AlignCenter)
       self.label_35 = QLabel(self.tab_11)
       self.label_35.setObjectName(u"label_35")
       self.label_35.setGeometry(QRect(600, 10, 371, 16))
       self.label_35.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_35.setAlignment(QtCore.Qt.AlignCenter)


       self.graphicsView_11.raise_()
       self.label_33.raise_()
       self.label_34.raise_()
       self.label_35.raise_()


       self.tab_12 = QWidget() # числівник
       self.tab_12.setObjectName(u"tab_12")
       self.tabWidget.addTab(self.tab_12, "")
       self.graphicsView_12 = QGraphicsView(self.tab_12)
       self.graphicsView_12.setObjectName(u"graphicsView_12")
       self.graphicsView_12.setGeometry(QtCore.QRect(600, 50, 371, 301))
       self.label_36 = QLabel(self.tab_12)
       self.label_36.setObjectName(u"label_36")
       self.label_36.setGeometry(QRect(0, 10, 406, 16))
       self.label_36.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_36.setAlignment(QtCore.Qt.AlignCenter)
       self.label_37 = QLabel(self.tab_12)
       self.label_37.setObjectName(u"label_37")
       self.label_37.setGeometry(QRect(426, 10, 155, 16))
       self.label_37.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_37.setAlignment(QtCore.Qt.AlignCenter)
       self.label_38 = QLabel(self.tab_12)
       self.label_38.setObjectName(u"label_38")
       self.label_38.setGeometry(QRect(600, 10, 371, 16))
       self.label_38.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_38.setAlignment(QtCore.Qt.AlignCenter)


       self.graphicsView_12.raise_()
       self.label_36.raise_()
       self.label_37.raise_()
       self.label_38.raise_()




       self.tab_13 = QWidget() # вигук
       self.tab_13.setObjectName(u"tab_13")
       self.tabWidget.addTab(self.tab_13, "")
       self.graphicsView_13 = QGraphicsView(self.tab_13)
       self.graphicsView_13.setObjectName(u"graphicsView_13")
       self.graphicsView_13.setGeometry(QtCore.QRect(600, 50, 371, 301))
       self.label_39 = QLabel(self.tab_13)
       self.label_39.setObjectName(u"label_39")
       self.label_39.setGeometry(QRect(0, 10, 406, 16))
       self.label_39.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_39.setAlignment(QtCore.Qt.AlignCenter)
       self.label_40 = QLabel(self.tab_13)
       self.label_40.setObjectName(u"label_40")
       self.label_40.setGeometry(QRect(426, 10, 155, 16))
       self.label_40.setStyleSheet("font: 10pt \"Arial\";\n"
               "background-color: rgb(170, 170, 255);\n"
               "border-color: rgb(0, 0, 127);")
       self.label_40.setAlignment(QtCore.Qt.AlignCenter)
       #self.label_41 = QLabel(self.tab_13)
       #self.label_41.setObjectName(u"label_41")
       #self.label_41.setGeometry(QRect(600, 10, 371, 16))
       #self.label_41.setStyleSheet("font: 10pt \"Arial\";\n"
       #        "background-color: rgb(170, 170, 255);\n"
       #        "border-color: rgb(0, 0, 127);")
       #self.label_41.setAlignment(QtCore.Qt.AlignCenter)


       self.graphicsView_13.raise_()
       self.label_39.raise_()
       self.label_40.raise_()
       self.label_41.raise_()



       self.horizontalLayout_2.addWidget(self.tabWidget)

       MainWindow.setCentralWidget(self.centralwidget)
       self.menubar = QMenuBar(MainWindow)
       self.menubar.setObjectName(u"menubar")
       self.menubar.setGeometry(QRect(0, 0, 891, 21))
       MainWindow.setMenuBar(self.menubar)
       self.statusbar = QStatusBar(MainWindow)
       self.statusbar.setObjectName(u"statusbar")
       MainWindow.setStatusBar(self.statusbar)

       self.retranslateUi(MainWindow)

       self.tabWidget.setCurrentIndex(0)
       self.tabWidget_2.setCurrentIndex(0)
       self.tabWidget_3.setCurrentIndex(1)
       self.tabWidget_4.setCurrentIndex(0)


       QMetaObject.connectSlotsByName(MainWindow)
   # setupUi

   def retranslateUi(self, MainWindow):
       _translate = QtCore.QCoreApplication.translate
       MainWindow.setWindowTitle(QCoreApplication.translate("MainWindow", u"MainWindow", None))
       self.label.setText(QCoreApplication.translate("MainWindow", u"Варіаційний ряд", None))
       self.label_2.setText(QCoreApplication.translate("MainWindow", u"Статистичні значення", None))
       self.label_3.setText(QCoreApplication.translate("MainWindow", u"Полігон частот", None))
       self.label_5.setText(QCoreApplication.translate("MainWindow", u"\u0412\u0430\u0440\u0456\u0430\u0446\u0456\u0439\u043d\u0438\u0439 \u0440\u044f\u0434", None))
       self.label_6.setText(QCoreApplication.translate("MainWindow", u"Варіаційний ряд", None))
       self.label_7.setText(QCoreApplication.translate("MainWindow", u"Статистичні значення", None))
       self.label_8.setText(QCoreApplication.translate("MainWindow", u"Полігон частот", None))
       self.label_9.setText(QCoreApplication.translate("MainWindow", u"Варіаційний ряд", None))
       self.label_10.setText(QCoreApplication.translate("MainWindow", u"Статистичні значення", None))
       self.label_11.setText(QCoreApplication.translate("MainWindow", u"Полігон частот", None))
       self.label_12.setText(QCoreApplication.translate("MainWindow", u"Варіаційний ряд", None))
       self.label_13.setText(QCoreApplication.translate("MainWindow", u"Статистичні значення", None))
       self.label_14.setText(QCoreApplication.translate("MainWindow", u"Полігон частот", None))
       self.label_15.setText(QCoreApplication.translate("MainWindow", u"Варіаційний ряд", None))
       self.label_16.setText(QCoreApplication.translate("MainWindow", u"Статистичні значення", None))
       self.label_17.setText(QCoreApplication.translate("MainWindow", u"Полігон частот", None))
       self.label_18.setText(QCoreApplication.translate("MainWindow", u"Варіаційний ряд", None))
       self.label_19.setText(QCoreApplication.translate("MainWindow", u"Статистичні значення", None))
       self.label_20.setText(QCoreApplication.translate("MainWindow", u"Полігон частот", None))
       self.label_21.setText(QCoreApplication.translate("MainWindow", u"Варіаційний ряд", None))
       self.label_22.setText(QCoreApplication.translate("MainWindow", u"Статистичні значення", None))
       self.label_23.setText(QCoreApplication.translate("MainWindow", u"Полігон частот", None))
       self.label_24.setText(QCoreApplication.translate("MainWindow", u"Варіаційний ряд", None))
       self.label_25.setText(QCoreApplication.translate("MainWindow", u"Статистичні значення", None))
       self.label_26.setText(QCoreApplication.translate("MainWindow", u"Полігон частот", None))
       self.label_27.setText(QCoreApplication.translate("MainWindow", u"Варіаційний ряд", None))
       self.label_28.setText(QCoreApplication.translate("MainWindow", u"Статистичні значення", None))
       self.label_29.setText(QCoreApplication.translate("MainWindow", u"Полігон частот", None))
       self.label_30.setText(QCoreApplication.translate("MainWindow", u"Варіаційний ряд", None))
       self.label_31.setText(QCoreApplication.translate("MainWindow", u"Статистичні значення", None))
       self.label_32.setText(QCoreApplication.translate("MainWindow", u"Полігон частот", None))
       self.label_33.setText(QCoreApplication.translate("MainWindow", u"Варіаційний ряд", None))
       self.label_34.setText(QCoreApplication.translate("MainWindow", u"Статистичні значення", None))
       self.label_35.setText(QCoreApplication.translate("MainWindow", u"Полігон частот", None))
       self.label_36.setText(QCoreApplication.translate("MainWindow", u"Варіаційний ряд", None))
       self.label_37.setText(QCoreApplication.translate("MainWindow", u"Статистичні значення", None))
       self.label_38.setText(QCoreApplication.translate("MainWindow", u"Полігон частот", None))
       self.label_39.setText(QCoreApplication.translate("MainWindow", u"Варіаційний ряд", None))
       self.label_40.setText(QCoreApplication.translate("MainWindow", u"Статистичні значення", None))
       #self.label_41.setText(QCoreApplication.translate("MainWindow", u"Полігон частот", None))
       #self.label_42.setText(QCoreApplication.translate("MainWindow", u"Варіаційний ряд", None))
       #self.label_43.setText(QCoreApplication.translate("MainWindow", u"Статистичні значення", None))
       #self.label_44.setText(QCoreApplication.translate("MainWindow", u"Полігон частот", None))
       self.tabWidget_2.setTabText(self.tabWidget_2.indexOf(self.tab_14), QCoreApplication.translate("MainWindow", u"Вибірка 1", None))
       self.tabWidget_2.setTabText(self.tabWidget_2.indexOf(self.tab_15), QCoreApplication.translate("MainWindow", u"Вибірка 2", None))
       self.tabWidget_3.setTabText(self.tabWidget_3.indexOf(self.tab_16), QCoreApplication.translate("MainWindow", u"Вибірка 1", None))
       self.tabWidget_3.setTabText(self.tabWidget_3.indexOf(self.tab_17), QCoreApplication.translate("MainWindow", u"Вибірка 2", None))
       self.tabWidget_4.setTabText(self.tabWidget_4.indexOf(self.tab_18), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1",
                                                                                                     None))
       self.tabWidget_4.setTabText(self.tabWidget_4.indexOf(self.tab_19), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2",
                                                                                                     None))
       self.tabWidget_5.setTabText(self.tabWidget_5.indexOf(self.tab_20), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1", None))
       self.tabWidget_5.setTabText(self.tabWidget_5.indexOf(self.tab_21), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2", None))
       self.tabWidget_6.setTabText(self.tabWidget_6.indexOf(self.tab_22), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1",
                                                                                                     None))
       self.tabWidget_6.setTabText(self.tabWidget_6.indexOf(self.tab_23), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2", None))
       self.tabWidget_7.setTabText(self.tabWidget_7.indexOf(self.tab_24), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1",
                                                                                                     None))
       self.tabWidget_7.setTabText(self.tabWidget_7.indexOf(self.tab_25), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2", None))
       self.tabWidget_8.setTabText(self.tabWidget_8.indexOf(self.tab_26), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1",
                                                                                                     None))
       self.tabWidget_8.setTabText(self.tabWidget_8.indexOf(self.tab_27), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2", None))
       self.tabWidget_9.setTabText(self.tabWidget_9.indexOf(self.tab_28), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1",
                                                                                                     None))
       self.tabWidget_9.setTabText(self.tabWidget_9.indexOf(self.tab_29), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2", None))
       self.tabWidget_10.setTabText(self.tabWidget_10.indexOf(self.tab_30), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1",
                                                                                                     None))
       self.tabWidget_10.setTabText(self.tabWidget_10.indexOf(self.tab_31), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2", None))
       self.tabWidget_11.setTabText(self.tabWidget_11.indexOf(self.tab_32), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1",
                                                                                                     None))
       self.tabWidget_11.setTabText(self.tabWidget_11.indexOf(self.tab_33), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2", None))

       self.tabWidget_12.setTabText(self.tabWidget_12.indexOf(self.tab_34), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1",
                                                                                                     None))
       self.tabWidget_12.setTabText(self.tabWidget_12.indexOf(self.tab_35), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2", None))

       self.tabWidget_13.setTabText(self.tabWidget_13.indexOf(self.tab_36), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1",
                                                                                                     None))
       self.tabWidget_13.setTabText(self.tabWidget_13.indexOf(self.tab_37), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2",
                                                                                                       None))
       self.tabWidget_14.setTabText(self.tabWidget_14.indexOf(self.tab_38), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1",
                                                                                                     None))
       self.tabWidget_14.setTabText(self.tabWidget_14.indexOf(self.tab_39), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2", None))
       self.tabWidget_15.setTabText(self.tabWidget_15.indexOf(self.tab_40), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1",
                                                                                                     None))
       self.tabWidget_15.setTabText(self.tabWidget_15.indexOf(self.tab_41), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2", None))
       self.tabWidget_16.setTabText(self.tabWidget_16.indexOf(self.tab_42), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1",
                                                                                                     None))
       self.tabWidget_16.setTabText(self.tabWidget_16.indexOf(self.tab_43), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2", None))
       self.tabWidget_17.setTabText(self.tabWidget_17.indexOf(self.tab_44), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1",
                                                                                                     None))
       self.tabWidget_17.setTabText(self.tabWidget_17.indexOf(self.tab_45), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2", None))
       self.tabWidget_18.setTabText(self.tabWidget_18.indexOf(self.tab_46), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1",
                                                                                                     None))
       self.tabWidget_18.setTabText(self.tabWidget_18.indexOf(self.tab_47), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2", None))
       self.tabWidget_19.setTabText(self.tabWidget_19.indexOf(self.tab_48), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 1",
                                                                                                     None))
       self.tabWidget_19.setTabText(self.tabWidget_19.indexOf(self.tab_49), QCoreApplication.translate("MainWindow",
                                                                                                     u"Вибірка 2", None))
       self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab), QCoreApplication.translate("MainWindow",
                                                                                              u"Іменник", None))
       self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_2), QCoreApplication.translate("MainWindow",
                                                                                                u"Прикметник", None))
       self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_3), QCoreApplication.translate("MainWindow", u"Дієслово", None))
       self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_4), QCoreApplication.translate("MainWindow",
                                                                                                u"Займенник", None))
       self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_5), QCoreApplication.translate("MainWindow",
                                                                                                u"Прислівник", None))
       self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_6), QCoreApplication.translate("MainWindow",
                                                                                                u"Прийменник", None))
       self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_7), QCoreApplication.translate("MainWindow",
                                                                                                u"Дієприслівник",
                                                                                                None))
       self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_8), QCoreApplication.translate("MainWindow",
                                                                                                u"Сполучник", None))
       self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_9), QCoreApplication.translate("MainWindow",
                                                                                                u"Частка", None))
       self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_10), QCoreApplication.translate("MainWindow",
                                                                                                 u"Предикатив", None))
       self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_11), QCoreApplication.translate("MainWindow",
                                                                                                 u"Компаратив", None))
       self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_12), QCoreApplication.translate("MainWindow",
                                                                                                 u"Числівник", None))
       self.tabWidget.setTabText(self.tabWidget.indexOf(self.tab_13), QCoreApplication.translate("MainWindow",
                                                                                                 u"Вигук", None))
   # retranslateUi

       def print_iformation():
           global my_text
           ni_in_interval_sigma = []
           ni_in_interval_2sigma = []
           ni_in_interval_3sigma = []
           ni_in_interval_sigma_sum = float
           ni_in_interval_2sigma_sum = float
           ni_in_interval_3sigma_sum = float
           try:
               x_aver_minus_sigma = int(rows[0][3][1:4])
           except ValueError:
               x_aver_minus_sigma = int(rows[0][3][1:3])
           try:
               x_aver_plus_sigma = int(rows[0][3][6:9])
           except ValueError:
               try:
                   x_aver_plus_sigma = int(rows[0][3][5:8])
               except ValueError:
                   x_aver_plus_sigma = int(rows[0][3][5:7])

           print(x_aver_minus_sigma, x_aver_plus_sigma)

           try:
               x_aver_minus_2sigma = int(rows[0][4][1:4])
           except ValueError:
               x_aver_minus_2sigma = int(rows[0][4][1:3])
           try:
               x_aver_plus_2sigma = int(rows[0][4][6:9])
           except ValueError:
               try:
                   x_aver_plus_2sigma = int(rows[0][4][5:8])
               except ValueError:
                   x_aver_plus_2sigma = int(rows[0][4][5:7])

           print(x_aver_minus_2sigma, x_aver_plus_2sigma)

           try:
               x_aver_minus_3sigma = int(rows[0][5][1:4])
           except ValueError:
               x_aver_minus_3sigma = int(rows[0][5][1:3])
           try:
               x_aver_plus_3sigma = int(rows[0][5][6:9])
           except ValueError:
               try:
                   x_aver_plus_3sigma = int(rows[0][5][5:8])
               except ValueError:
                   x_aver_plus_3sigma = int(rows[0][5][5:7])

           print(x_aver_minus_3sigma, x_aver_plus_3sigma)

           try:
                   x_aver_minus_sigma_x_aver = int(rows[0][6][1:4])
           except ValueError:
               x_aver_minus_sigma_x_aver = int(rows[0][6][1:3])
           try:
               x_aver_plus_sigma_x_aver = int(rows[0][6][6:9])
           except ValueError:
               try:
                   x_aver_plus_sigma_x_aver = int(rows[0][6][5:8])
               except ValueError:
                   x_aver_plus_sigma_x_aver = int(rows[0][6][5:7])

           try:
               x_aver_minus_2sigma_x_aver = int(rows[0][7][1:4])
           except ValueError:
               x_aver_minus_2sigma_x_aver = int(rows[0][7][1:3])
           try:
               x_aver_plus_2sigma_x_aver = int(rows[0][7][6:9])
           except ValueError:
               try:
                   x_aver_plus_2sigma_x_aver = int(rows[0][7][5:8])
               except ValueError:
                   x_aver_plus_2sigma_x_aver = int(rows[0][7][5:7])

           try:
               x_aver_minus_3sigma_x_aver = int(rows[0][8][1:4])
           except ValueError:
               x_aver_minus_3sigma_x_aver = int(rows[0][8][1:3])
           try:
               x_aver_plus_3sigma_x_aver = int(rows[0][8][6:9])
           except ValueError:
               try:
                   x_aver_plus_3sigma_x_aver = int(rows[0][8][5:8])
               except ValueError:
                   x_aver_plus_3sigma_x_aver = int(rows[0][8][5:7])

           for i in xi_and_ni:
               if i[0] in range(x_aver_minus_sigma, x_aver_plus_sigma+1):
                   ni_in_interval_sigma.append(i[1])
                   ni_in_interval_sigma_sum = sum(ni_in_interval_sigma)
               if i[0] in range(x_aver_minus_2sigma, x_aver_plus_2sigma+1):
                   ni_in_interval_2sigma.append(i[1])
                   ni_in_interval_2sigma_sum = sum(ni_in_interval_2sigma)
               if i[0] in range(x_aver_minus_3sigma, x_aver_plus_3sigma+1):
                   ni_in_interval_3sigma.append(i[1])
                   ni_in_interval_3sigma_sum = sum(ni_in_interval_3sigma)
           percentage = round(ni_in_interval_sigma_sum*100/ni_sum, 1)
           percentage2 = round(ni_in_interval_2sigma_sum*100/ni_sum, 1)
           percentage3 = round(ni_in_interval_3sigma_sum*100/ni_sum, 1)

           my_text = 'В інтервалі x сер. ± сігма знаходиться ' + "(" + str(ni_in_interval_sigma_sum) + ') -  ' + str(
                   percentage) + '% абсолютниих частот.'

           if round((68.3 - percentage)*100/68.3, 1) < 5:
                   my_text+= '\n' + 'Це вказує на хорошу узгодженіcть теоретично обчисленого й емпіричного результату'
           else:
                   my_text+= '\n' + 'Це вказує на погану узгодженіcть теоретично обчисленого й емпіричного результату'


           my_text += '\n' + '\n' +'В інтервалі x сер. ± 2*сігма знаходиться ' + "(" + str(ni_in_interval_2sigma_sum) + ')' \
                                                                                                                  ' -  ' + \
                   str(
                   percentage2) + '% абсолютниих частот.'

           if round((95.5 - percentage2)*100/95.5, 1) < 5:
                   my_text+= '\n' + 'Це вказує на хорошу узгодженіcть теоретично обчисленого й емпіричного результату'
           else:
                   my_text+= '\n' + 'Це вказує на погану узгодженіcть теоретично обчисленого й емпіричного результату'

           my_text += '\n' + '\n' + 'В інтервалі x сер. ± 3*сігма знаходиться ' + "(" + str(ni_in_interval_3sigma_sum) + \
                ') -  ' + \
                   str(
                   percentage3) + '% абсолютниих частот.'

           if round((99.7 - percentage3)*100/99.7, 1) < 5:
                   my_text+= '\n' + 'Це вказує на хорошу узгодженіcть теоретично обчисленого й емпіричного результату'
           else:
                   my_text+= '\n' + 'Це вказує на погану узгодженіcть теоретично обчисленого й емпіричного результату'

           my_text+= '\n' + '\n' +'З імовірністю 68.3% ми можемо стверджувати, що в даній генеральній сукупності середня ' \
                               'частота даної частини мови коливатиметься в межах ' + 'від '+ str(x_aver_minus_sigma_x_aver)\
                  + ' до ' + str(x_aver_plus_sigma_x_aver)

           my_text+= '\n' + '\n' +'З імовірністю 95.5% ми можемо стверджувати, що в даній генеральній сукупності середня ' \
                               'частота даної частини мови коливатиметься в межах ' + 'від '+ str(x_aver_minus_2sigma_x_aver)\
                  + ' до ' + str(x_aver_plus_2sigma_x_aver)

           my_text+= '\n' + '\n' +'З імовірністю 99.7% ми можемо стверджувати, що в даній генеральній сукупності середня ' \
                               'частота даної частини мови коливатиметься в межах ' + 'від '+ str(x_aver_minus_3sigma_x_aver)\
                  + ' до ' + str(x_aver_plus_3sigma_x_aver)
           return my_text

       def interval_row(K, xi):
           global interval_row_list # список з межами інтервалів і серединами
           global ni_in_intervals   # список з кількостями хі в кожному інтервалі
           R = max(xi) - min(xi)
           h = R/K
           interval_row_list = []
           ni_in_intervals = []
           xini_intervals = []
           for i in range(0, K):
               interval_row_list.append([min(xi)+i*h, round((min(xi)+i*h)+h, 1), round((min(xi)+i*h)+h/2, 1)])
               ni_for_one_interval = []
               for o in xi_and_ni:
                   if min(xi)+i*h <= o[0] <= (min(xi)+i*h)+h:
                       ni_for_one_interval.append(o[1])
                   else:
                       continue
               ni_in_intervals.append(ni_for_one_interval)
               xini_intervals.append([round((min(xi)+i*h)+h/2, 1), sum(ni_for_one_interval)])
           ni_interval_sum = []
           xini_intervals_sum = []
           for i in xini_intervals:
               ni_interval_sum.append(i[1])
               xini_intervals_sum.append(i[0]*i[1])
           ni_interval_sum = sum(ni_interval_sum)
           xini_intervals_sum = sum(xini_intervals_sum)
           x_aver_interval = xini_intervals_sum/ni_interval_sum

       cursor.execute('SELECT * FROM іменник_середня_частота')
       rows = cursor.fetchall()

       row = 0
       for i in rows:
           x = len(rows)

           self.tableWidget.setRowCount(x)
           col = 0
           for item in i:
                   # Захищаємо вміст колонок від змін користувача
                   cellinfo = QTableWidgetItem(str(round(item)))
                   cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
                   )
                   self.tableWidget.setItem(row, col, cellinfo) #додоаємо рядки в таблицю
                   col += 1
           row += 1

       xi_and_ni = []
       xi = []
       ni = []
       for i in rows:
           xi_and_ni.append([i[1], i[2]])
           xi.append(i[1])
           ni.append(i[2])
       ni_sum = sum(ni)




       cursor.execute('SELECT * FROM іменник_статистичні_дані')
       rows = cursor.fetchall()
       headings = ['σ', 'σх̅', 'інт. із σ', 'інт. із 2σ', 'інт. із 3σ', 'інт. σх̅', 'інт. 2σх̅', 'інт. 3σх̅',
                       'V', 'Vmax', 'D', 'похибка']
       row = 0
       for i in rows:
           for item in i[1:13]:
                   # Захищаємо вміст колонок від змін користувача
               try:
                   cellinfo = QTableWidgetItem(str(round(item, 2)))
               except:
                   cellinfo = QTableWidgetItem(str(item))
               cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
               )
               self.tableWidget_2.setItem(row, 1, cellinfo) #додаємо рядки в таблицю
               row += 1
       row = 0
       for i in headings:
           cellinfo = QTableWidgetItem(i)
           cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
           )
           self.tableWidget_2.setItem(row, 0, cellinfo)
           row += 1

       self.tableWidget_2.resizeColumnsToContents()


       print_iformation()
       self.label_4.setText(QCoreApplication.translate("MainWindow", my_text, None))


       interval_row(5, xi)
       xi_interval = []
       ni_interval = []
       for i in interval_row_list:
           xi_interval.append(i[2])

       for i in ni_in_intervals:
           ni_interval.append(sum(i))

       pen = pg.mkPen(color='b')
       self.graphWidget.plot(xi_interval, ni_interval, name ='Вибірка 1', pen=pen, symbol='+', symbolSize=5,
                             symbolBrush=('b'))




       cursor.execute('SELECT * FROM іменник_середня_частота_2')
       rows = cursor.fetchall()

       row = 0
       for i in rows:
           x = len(rows)

           self.tableWidget_3.setRowCount(x)
           col = 0
           for item in i:
                   # Захищаємо вміст колонок від змін користувача
                   cellinfo = QTableWidgetItem(str(round(item)))
                   cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
                   )
                   self.tableWidget_3.setItem(row, col, cellinfo) #додоаємо рядки в таблицю
                   col += 1
           row += 1

       xi_and_ni = []
       xi = []
       ni = []
       for i in rows:
           xi_and_ni.append([i[1], i[2]])
           xi.append(i[1])
           ni.append(i[2])
       ni_sum = sum(ni)


       cursor.execute('SELECT * FROM іменник_статистичні_дані_2')
       rows = cursor.fetchall()
       row = 0
       for i in rows:
           #col = 0
           for item in i[1:13]:
                   # Захищаємо вміст колонок від змін користувача
               try:
                   cellinfo = QTableWidgetItem(str(round(item, 2)))
               except:
                   cellinfo = QTableWidgetItem(str(item))
               cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
               )
               self.tableWidget_4.setItem(row, 1, cellinfo) #додаємо рядки в таблицю
               #col += 1
               row += 1
       row = 0
       for i in headings:
           cellinfo = QTableWidgetItem(i)
           cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
           )
           self.tableWidget_4.setItem(row, 0, cellinfo)
           row += 1
       self.tableWidget_4.resizeColumnsToContents()

       print_iformation()
       self.label_5.setText(QCoreApplication.translate("MainWindow", my_text, None))


       interval_row(11, xi)
       xi_interval = []
       ni_interval = []
       for i in interval_row_list:
           xi_interval.append(i[2])

       for i in ni_in_intervals:
           ni_interval.append(sum(i))


       pen = pg.mkPen(color='r')
       self.graphWidget.plot(xi_interval, ni_interval, name ='Вибірка 2', pen=pen, symbol='+', symbolSize=5,
                             symbolBrush=('r'))



       cursor.execute('SELECT * FROM прикметник_середня_частота')
       rows = cursor.fetchall()

       row = 0
       for i in rows:
           x = len(rows)

           self.tableWidget_5.setRowCount(x)
           col = 0
           for item in i:
                   # Захищаємо вміст колонок від змін користувача
                   cellinfo = QTableWidgetItem(str(round(item)))
                   cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
                   )
                   self.tableWidget_5.setItem(row, col, cellinfo) #додоаємо рядки в таблицю
                   col += 1
           row += 1
       self.tableWidget_5.resizeColumnsToContents()

       xi_and_ni = []
       xi = []
       ni = []
       for i in rows:
           xi_and_ni.append([i[1], i[2]])
           xi.append(i[1])
           ni.append(i[2])
       ni_sum = sum(ni)


       cursor.execute('SELECT * FROM прикметник_статистичні_дані')
       rows = cursor.fetchall()
       headings = ['σ', 'σх̅', 'інт. із σ', 'інт. із 2σ', 'інт. із 3σ', 'інт. σх̅', 'інт. 2σх̅', 'інт. 3σх̅',
                       'V', 'Vmax', 'D', 'похибка']
       row = 0
       for i in rows:
           for item in i[1:13]:
                   # Захищаємо вміст колонок від змін користувача
               try:
                   cellinfo = QTableWidgetItem(str(round(item, 2)))
               except:
                   cellinfo = QTableWidgetItem(str(item))
               cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
               )
               self.tableWidget_7.setItem(row, 1, cellinfo) #додаємо рядки в таблицю
               row += 1
       row = 0
       for i in headings:
           cellinfo = QTableWidgetItem(i)
           cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
           )
           self.tableWidget_7.setItem(row, 0, cellinfo)
           row += 1

       self.tableWidget_7.resizeColumnsToContents()

       print_iformation()
       self.label_41.setText(QCoreApplication.translate("MainWindow", my_text, None))

       interval_row(7, xi)
       xi_interval = []
       ni_interval = []
       for i in interval_row_list:
           xi_interval.append(i[2])

       for i in ni_in_intervals:
           ni_interval.append(sum(i))

       pen = pg.mkPen(color='b')
       self.graphWidget_2.plot(xi_interval, ni_interval, name ='Вибірка 1', pen=pen, symbol='+', symbolSize=5,
                             symbolBrush=('b'))




       cursor.execute('SELECT * FROM прикметник_середня_частота_2')
       rows = cursor.fetchall()

       row = 0
       for i in rows:
           x = len(rows)

           self.tableWidget_6.setRowCount(x)
           col = 0
           for item in i:
                   # Захищаємо вміст колонок від змін користувача
                   cellinfo = QTableWidgetItem(str(round(item)))
                   cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
                   )
                   self.tableWidget_6.setItem(row, col, cellinfo) #додоаємо рядки в таблицю
                   col += 1
           row += 1
       self.tableWidget_6.resizeColumnsToContents()

       xi_and_ni = []
       xi = []
       ni = []
       for i in rows:
           xi_and_ni.append([i[1], i[2]])
           xi.append(i[1])
           ni.append(i[2])
       ni_sum = sum(ni)


       cursor.execute('SELECT * FROM прикметник_статистичні_дані_2')
       rows = cursor.fetchall()
       row = 0
       for i in rows:
           #col = 0
           for item in i[1:13]:
                   # Захищаємо вміст колонок від змін користувача
               try:
                   cellinfo = QTableWidgetItem(str(round(item, 2)))
               except:
                   cellinfo = QTableWidgetItem(str(item))
               cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
               )
               self.tableWidget_8.setItem(row, 1, cellinfo) #додаємо рядки в таблицю
               #col += 1
               row += 1
       row = 0
       for i in headings:
           cellinfo = QTableWidgetItem(i)
           cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
           )
           self.tableWidget_8.setItem(row, 0, cellinfo)
           row += 1
       self.tableWidget_8.resizeColumnsToContents()


       print_iformation()
       self.label_42.setText(QCoreApplication.translate("MainWindow", my_text, None))

       interval_row(5, xi)
       xi_interval = []
       ni_interval = []
       for i in interval_row_list:
           xi_interval.append(i[2])

       for i in ni_in_intervals:
           ni_interval.append(sum(i))

       pen = pg.mkPen(color='r')
       self.graphWidget_2.plot(xi_interval, ni_interval, name ='Вибірка 2', pen=pen, symbol='+', symbolSize=5,
                             symbolBrush=('r'))




       cursor.execute('SELECT * FROM дієслово_середня_частота')
       rows = cursor.fetchall()

       row = 0
       for i in rows:
           x = len(rows)

           self.tableWidget_9.setRowCount(x)
           col = 0
           for item in i:
                   # Захищаємо вміст колонок від змін користувача
                   cellinfo = QTableWidgetItem(str(round(item)))
                   cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
                   )
                   self.tableWidget_9.setItem(row, col, cellinfo) #додоаємо рядки в таблицю
                   col += 1
           row += 1
       self.tableWidget_9.resizeColumnsToContents()

       ni_in_interval_sigma = []
       xi_and_ni = []
       ni_in_interval_sigma_sum = float
       xi = []
       ni = []
       for i in rows:
           xi_and_ni.append([i[1], i[2]])
           xi.append(i[1])
           ni.append(i[2])
       ni_sum = sum(ni)


       cursor.execute('SELECT * FROM дієслово_статистичні_дані')
       rows = cursor.fetchall()
       headings = ['σ', 'σх̅', 'інт. із σ', 'інт. із 2σ', 'інт. із 3σ', 'інт. σх̅', 'інт. 2σх̅', 'інт. 3σх̅',
                       'V', 'Vmax', 'D', 'похибка']
       row = 0
       for i in rows:
           for item in i[1:13]:
                   # Захищаємо вміст колонок від змін користувача
               try:
                   cellinfo = QTableWidgetItem(str(round(item, 2)))
               except:
                   cellinfo = QTableWidgetItem(str(item))
               cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
               )
               self.tableWidget_11.setItem(row, 1, cellinfo) #додаємо рядки в таблицю
               row += 1
       row = 0
       for i in headings:
           cellinfo = QTableWidgetItem(i)
           cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
           )
           self.tableWidget_11.setItem(row, 0, cellinfo)
           row += 1

       self.tableWidget_11.resizeColumnsToContents()

       print_iformation()
       self.label_43.setText(QCoreApplication.translate("MainWindow", my_text, None))

       interval_row(9, xi)
       xi_interval = []
       ni_interval = []
       for i in interval_row_list:
           xi_interval.append(i[2])

       for i in ni_in_intervals:
           ni_interval.append(sum(i))

       pen = pg.mkPen(color='b')
       self.graphWidget_3.plot(xi_interval, ni_interval, name ='Вибірка 1', pen=pen, symbol='+', symbolSize=5,
                             symbolBrush=('b'))



       cursor.execute('SELECT * FROM дієслово_середня_частота_2')
       rows = cursor.fetchall()

       row = 0
       for i in rows:
           x = len(rows)

           self.tableWidget_10.setRowCount(x)
           col = 0
           for item in i:
                   # Захищаємо вміст колонок від змін користувача
                   cellinfo = QTableWidgetItem(str(round(item)))
                   cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
                   )
                   self.tableWidget_10.setItem(row, col, cellinfo) #додоаємо рядки в таблицю
                   col += 1
           row += 1
       self.tableWidget_10.resizeColumnsToContents()

       ni_in_interval_sigma = []
       xi_and_ni = []
       ni_in_interval_sigma_sum = float
       xi = []
       ni = []
       for i in rows:
           xi_and_ni.append([i[1], i[2]])
           xi.append(i[1])
           ni.append(i[2])
       ni_sum = sum(ni)


       cursor.execute('SELECT * FROM дієслово_статистичні_дані_2')
       rows = cursor.fetchall()
       row = 0
       for i in rows:
           #col = 0
           for item in i[1:13]:
                   # Захищаємо вміст колонок від змін користувача
               try:
                   cellinfo = QTableWidgetItem(str(round(item, 2)))
               except:
                   cellinfo = QTableWidgetItem(str(item))
               cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
               )
               self.tableWidget_12.setItem(row, 1, cellinfo) #додаємо рядки в таблицю
               #col += 1
               row += 1
       row = 0
       for i in headings:
           cellinfo = QTableWidgetItem(i)
           cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
           )
           self.tableWidget_12.setItem(row, 0, cellinfo)
           row += 1
       self.tableWidget_12.resizeColumnsToContents()

       print_iformation()
       self.label_44.setText(QCoreApplication.translate("MainWindow", my_text, None))

       interval_row(7, xi)
       xi_interval = []
       ni_interval = []
       for i in interval_row_list:
           xi_interval.append(i[2])

       for i in ni_in_intervals:
           ni_interval.append(sum(i))

       pen = pg.mkPen(color='r')
       self.graphWidget_3.plot(xi_interval, ni_interval, name ='Вибірка 2', pen=pen, symbol='+', symbolSize=5,
                             symbolBrush=('r'))


       cursor.execute('SELECT * FROM займенниковий_іменник_середня_частота')
       rows = cursor.fetchall()
       row = 0
       for i in rows:
           x = len(rows)

           self.tableWidget_13.setRowCount(x)
           col = 0
           for item in i:
                   # Захищаємо вміст колонок від змін користувача
                   cellinfo = QTableWidgetItem(str(round(item)))
                   cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
                   )
                   self.tableWidget_13.setItem(row, col, cellinfo) #додоаємо рядки в таблицю
                   col += 1
           row += 1
       self.tableWidget_13.resizeColumnsToContents()

       ni_in_interval_sigma = []
       xi_and_ni = []
       ni_in_interval_sigma_sum = float
       xi = []
       ni = []
       for i in rows:
           xi_and_ni.append([i[1], i[2]])
           xi.append(i[1])
           ni.append(i[2])
       ni_sum = sum(ni)




       cursor.execute('SELECT * FROM займенниковий_іменник_статистичні_дані')
       rows = cursor.fetchall()
       headings = ['σ', 'σх̅', 'інт. із σ', 'інт. із 2σ', 'інт. із 3σ', 'інт. σх̅', 'інт. 2σх̅', 'інт. 3σх̅',
                       'V', 'Vmax', 'D', 'похибка']
       row = 0
       for i in rows:
           for item in i[1:13]:
                   # Захищаємо вміст колонок від змін користувача
               try:
                   cellinfo = QTableWidgetItem(str(round(item, 2)))
               except:
                   cellinfo = QTableWidgetItem(str(item))
               cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
               )
               self.tableWidget_15.setItem(row, 1, cellinfo) #додаємо рядки в таблицю
               row += 1
       row = 0
       for i in headings:
           cellinfo = QTableWidgetItem(i)
           cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
           )
           self.tableWidget_15.setItem(row, 0, cellinfo)
           row += 1

       self.tableWidget_15.resizeColumnsToContents()


       print_iformation()
       self.label_45.setText(QCoreApplication.translate("MainWindow", my_text, None))

       interval_row(9, xi)
       xi_interval = []
       ni_interval = []
       for i in interval_row_list:
           xi_interval.append(i[2])

       for i in ni_in_intervals:
           ni_interval.append(sum(i))

       pen = pg.mkPen(color='b')
       self.graphWidget_4.plot(xi_interval, ni_interval, name ='Вибірка 1', pen=pen, symbol='+', symbolSize=5,
                             symbolBrush=('b'))



       cursor.execute('SELECT * FROM займенниковий_іменник_середня_частота_2')
       rows = cursor.fetchall()
       row = 0
       for i in rows:
           x = len(rows)

           self.tableWidget_14.setRowCount(x)
           col = 0
           for item in i:
                   # Захищаємо вміст колонок від змін користувача
                   cellinfo = QTableWidgetItem(str(round(item)))
                   cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
                   )
                   self.tableWidget_14.setItem(row, col, cellinfo) #додоаємо рядки в таблицю
                   col += 1
           row += 1
       self.tableWidget_14.resizeColumnsToContents()

       ni_in_interval_sigma = []
       xi_and_ni = []
       ni_in_interval_sigma_sum = float
       xi = []
       ni = []
       for i in rows:
           xi_and_ni.append([i[1], i[2]])
           xi.append(i[1])
           ni.append(i[2])
       ni_sum = sum(ni)



       cursor.execute('SELECT * FROM займенниковий_іменник_статистичні_дані_2')
       rows = cursor.fetchall()
       row = 0
       for i in rows:
           #col = 0
           for item in i[1:13]:
                   # Захищаємо вміст колонок від змін користувача
               try:
                   cellinfo = QTableWidgetItem(str(round(item, 2)))
               except:
                   cellinfo = QTableWidgetItem(str(item))
               cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
               )
               self.tableWidget_16.setItem(row, 1, cellinfo) #додаємо рядки в таблицю
               #col += 1
               row += 1
       row = 0
       for i in headings:
           cellinfo = QTableWidgetItem(i)
           cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
           )
           self.tableWidget_16.setItem(row, 0, cellinfo)
           row += 1
       self.tableWidget_16.resizeColumnsToContents()

       print_iformation()
       self.label_46.setText(QCoreApplication.translate("MainWindow", my_text, None))

       interval_row(5, xi)
       xi_interval = []
       ni_interval = []
       for i in interval_row_list:
           xi_interval.append(i[2])

       for i in ni_in_intervals:
           ni_interval.append(sum(i))

       pen = pg.mkPen(color='r')
       self.graphWidget_4.plot(xi_interval, ni_interval, name ='Вибірка 2', pen=pen, symbol='+', symbolSize=5,
                             symbolBrush=('r'))


       cursor.execute('SELECT * FROM прислівник_середня_частота')
       rows = cursor.fetchall()

       row = 0
       for i in rows:
           x = len(rows)

           self.tableWidget_17.setRowCount(x)
           col = 0
           for item in i:
                   # Захищаємо вміст колонок від змін користувача
                   cellinfo = QTableWidgetItem(str(round(item)))
                   cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
                   )
                   self.tableWidget_17.setItem(row, col, cellinfo) #додоаємо рядки в таблицю
                   col += 1
           row += 1
       self.tableWidget_17.resizeColumnsToContents()

       ni_in_interval_sigma = []
       xi_and_ni = []
       ni_in_interval_sigma_sum = float
       xi = []
       ni = []
       for i in rows:
           xi_and_ni.append([i[1], i[2]])
           xi.append(i[1])
           ni.append(i[2])
       ni_sum = sum(ni)



       cursor.execute('SELECT * FROM прислівник_статистичні_дані')
       rows = cursor.fetchall()
       headings = ['σ', 'σх̅', 'інт. із σ', 'інт. із 2σ', 'інт. із 3σ', 'інт. σх̅', 'інт. 2σх̅', 'інт. 3σх̅',
                       'V', 'Vmax', 'D', 'похибка']
       row = 0
       for i in rows:
           for item in i[1:13]:
                   # Захищаємо вміст колонок від змін користувача
               try:
                   cellinfo = QTableWidgetItem(str(round(item, 2)))
               except:
                   cellinfo = QTableWidgetItem(str(item))
               cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
               )
               self.tableWidget_19.setItem(row, 1, cellinfo) #додаємо рядки в таблицю
               row += 1
       row = 0
       for i in headings:
           cellinfo = QTableWidgetItem(i)
           cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
           )
           self.tableWidget_19.setItem(row, 0, cellinfo)
           row += 1

       self.tableWidget_19.resizeColumnsToContents()

       print_iformation()
       self.label_47.setText(QCoreApplication.translate("MainWindow", my_text, None))

       interval_row(7, xi)
       xi_interval = []
       ni_interval = []
       for i in interval_row_list:
           xi_interval.append(i[2])

       for i in ni_in_intervals:
           ni_interval.append(sum(i))

       pen = pg.mkPen(color='b')
       self.graphWidget_5.plot(xi_interval, ni_interval, name ='Вибірка 1', pen=pen, symbol='+', symbolSize=5,
                             symbolBrush=('b'))



       cursor.execute('SELECT * FROM прислівник_середня_частота_2')
       rows = cursor.fetchall()

       row = 0
       for i in rows:
           x = len(rows)

           self.tableWidget_18.setRowCount(x)
           col = 0
           for item in i:
                   # Захищаємо вміст колонок від змін користувача
                   cellinfo = QTableWidgetItem(str(round(item)))
                   cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
                   )
                   self.tableWidget_18.setItem(row, col, cellinfo) #додоаємо рядки в таблицю
                   col += 1
           row += 1
       self.tableWidget_18.resizeColumnsToContents()

       ni_in_interval_sigma = []
       xi_and_ni = []
       ni_in_interval_sigma_sum = float
       xi = []
       ni = []
       for i in rows:
           xi_and_ni.append([i[1], i[2]])
           xi.append(i[1])
           ni.append(i[2])
       ni_sum = sum(ni)



       cursor.execute('SELECT * FROM прислівник_статистичні_дані_2')
       rows = cursor.fetchall()
       row = 0
       for i in rows:
           #col = 0
           for item in i[1:13]:
                   # Захищаємо вміст колонок від змін користувача
               try:
                   cellinfo = QTableWidgetItem(str(round(item, 2)))
               except:
                   cellinfo = QTableWidgetItem(str(item))
               cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
               )
               self.tableWidget_20.setItem(row, 1, cellinfo) #додаємо рядки в таблицю
               #col += 1
               row += 1
       row = 0
       for i in headings:
           cellinfo = QTableWidgetItem(i)
           cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
           )
           self.tableWidget_20.setItem(row, 0, cellinfo)
           row += 1
       self.tableWidget_20.resizeColumnsToContents()

       print_iformation()
       self.label_48.setText(QCoreApplication.translate("MainWindow", my_text, None))

       interval_row(5, xi)
       xi_interval = []
       ni_interval = []
       for i in interval_row_list:
           xi_interval.append(i[2])

       for i in ni_in_intervals:
           ni_interval.append(sum(i))

       pen = pg.mkPen(color='r')
       self.graphWidget_5.plot(xi_interval, ni_interval, name ='Вибірка 2', pen=pen, symbol='+', symbolSize=5,
                             symbolBrush=('r'))



       cursor.execute('SELECT * FROM прийменник_середня_частота')
       rows = cursor.fetchall()

       row = 0
       for i in rows:
           x = len(rows)

           self.tableWidget_21.setRowCount(x)
           col = 0
           for item in i:
                   # Захищаємо вміст колонок від змін користувача
                   cellinfo = QTableWidgetItem(str(round(item)))
                   cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
                   )
                   self.tableWidget_21.setItem(row, col, cellinfo) #додоаємо рядки в таблицю
                   col += 1
           row += 1
       self.tableWidget_21.resizeColumnsToContents()

       ni_in_interval_sigma = []
       xi_and_ni = []
       ni_in_interval_sigma_sum = float
       xi = []
       ni = []
       for i in rows:
           xi_and_ni.append([i[1], i[2]])
           xi.append(i[1])
           ni.append(i[2])
       ni_sum = sum(ni)





       cursor.execute('SELECT * FROM прийменник_статистичні_дані')
       rows = cursor.fetchall()
       headings = ['σ', 'σх̅', 'інт. із σ', 'інт. із 2σ', 'інт. із 3σ', 'інт. σх̅', 'інт. 2σх̅', 'інт. 3σх̅',
                       'V', 'Vmax', 'D', 'похибка']
       row = 0
       for i in rows:
           for item in i[1:13]:
                   # Захищаємо вміст колонок від змін користувача
               try:
                   cellinfo = QTableWidgetItem(str(round(item, 2)))
               except:
                   cellinfo = QTableWidgetItem(str(item))
               cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
               )
               self.tableWidget_23.setItem(row, 1, cellinfo) #додаємо рядки в таблицю
               row += 1
       row = 0
       for i in headings:
           cellinfo = QTableWidgetItem(i)
           cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
           )
           self.tableWidget_23.setItem(row, 0, cellinfo)
           row += 1

       self.tableWidget_23.resizeColumnsToContents()

       x_aver_minus_sigma = int(rows[0][3][1:3])
       x_aver_plus_sigma = int(rows[0][3][5:7])
       for i in xi_and_ni:
           if i[0] in range(x_aver_minus_sigma, x_aver_plus_sigma+1):
               ni_in_interval_sigma.append(i[1])
               ni_in_interval_sigma_sum = sum(ni_in_interval_sigma)
       percentage = round(ni_in_interval_sigma_sum*100/ni_sum, 1)

       text = 'В інтервалі x сер. ± сігма знаходиться ' + "(" + str(ni_in_interval_sigma_sum) + ') -  ' + str(
           percentage) + '% абсолютниих частот.'

       if round((68.3 - percentage)*100/68.3, 1) < 5:
           text+= '\n' + 'Це вказує на хорошу узгодженіcть теоретично обчисленого й емпіричного результату'
       else:
           text+= '\n' + 'Це вказує на погану узгодженіcть теоретично обчисленого й емпіричного результату'

       #self.label_49.setText(QCoreApplication.translate("MainWindow", text, None))

       interval_row(7, xi)
       xi_interval = []
       ni_interval = []
       for i in interval_row_list:
           xi_interval.append(i[2])

       for i in ni_in_intervals:
           ni_interval.append(sum(i))

       pen = pg.mkPen(color='b')
       self.graphWidget_6.plot(xi_interval, ni_interval, name ='Вибірка 1', pen=pen, symbol='+', symbolSize=5,
                             symbolBrush=('b'))


       cursor.execute('SELECT * FROM прийменник_середня_частота_2')
       rows = cursor.fetchall()

       row = 0
       for i in rows:
           x = len(rows)

           self.tableWidget_22.setRowCount(x)
           col = 0
           for item in i:
                   # Захищаємо вміст колонок від змін користувача
                   cellinfo = QTableWidgetItem(str(round(item)))
                   cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
                   )
                   self.tableWidget_22.setItem(row, col, cellinfo) #додоаємо рядки в таблицю
                   col += 1
           row += 1
       self.tableWidget_22.resizeColumnsToContents()

       ni_in_interval_sigma = []
       xi_and_ni = []
       ni_in_interval_sigma_sum = float
       xi = []
       ni = []
       for i in rows:
           xi_and_ni.append([i[1], i[2]])
           xi.append(i[1])
           ni.append(i[2])
       ni_sum = sum(ni)



       cursor.execute('SELECT * FROM прийменник_статистичні_дані_2')
       rows = cursor.fetchall()
       row = 0
       for i in rows:
           #col = 0
           for item in i[1:13]:
                   # Захищаємо вміст колонок від змін користувача
               try:
                   cellinfo = QTableWidgetItem(str(round(item, 2)))
               except:
                   cellinfo = QTableWidgetItem(str(item))
               cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
               )
               self.tableWidget_24.setItem(row, 1, cellinfo) #додаємо рядки в таблицю
               #col += 1
               row += 1
       row = 0
       for i in headings:
           cellinfo = QTableWidgetItem(i)
           cellinfo.setFlags(
                           QtCore.Qt.ItemIsSelectable | QtCore.Qt.ItemIsEnabled
           )
           self.tableWidget_24.setItem(row, 0, cellinfo)
           row += 1
       self.tableWidget_24.resizeColumnsToContents()

       x_aver_minus_sigma = int(rows[0][3][1:3])
       x_aver_plus_sigma = int(rows[0][3][5:7])
       for i in xi_and_ni:
           if i[0] in range(x_aver_minus_sigma, x_aver_plus_sigma+1):
               ni_in_interval_sigma.append(i[1])
               ni_in_interval_sigma_sum = sum(ni_in_interval_sigma)
       percentage = round(ni_in_interval_sigma_sum*100/ni_sum, 1)

       text = 'В інтервалі x сер. ± сігма знаходиться ' + "(" + str(ni_in_interval_sigma_sum) + ') -  ' + str(
           percentage) + '% абсолютниих частот.'

       if round((68.3 - percentage)*100/68.3, 1) < 5:
           text+= '\n' + 'Це вказує на хорошу узгодженіcть теоретично обчисленого й емпіричного результату'
       else:
           text+= '\n' + 'Це вказує на погану узгодженіcть теоретично обчисленого й емпіричного результату'

       #self.label_50.setText(QCoreApplication.translate("MainWindow", text, None))

       interval_row(7, xi)
       xi_interval = []
       ni_interval = []
       for i in interval_row_list:
           xi_interval.append(i[2])

       for i in ni_in_intervals:
           ni_interval.append(sum(i))

       pen = pg.mkPen(color='r')
       self.graphWidget_6.plot(xi_interval, ni_interval, name ='Вибірка 2', pen=pen, symbol='+', symbolSize=5,
                             symbolBrush=('r'))




if __name__ == "__main__":
   import sys
   app = QtWidgets.QApplication(sys.argv)
   MainWindow = QtWidgets.QMainWindow()
   ui = Ui_MainWindow()
   ui.setupUi(MainWindow)
   MainWindow.show()
   sys.exit(app.exec_())

conn.close()
